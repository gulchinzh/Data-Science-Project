# %% [markdown]
# ##                      Exploratory Data Analysis (EDA) Project   🏸🧪💻🚀👩‍💻

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_json("C:/Users/rusla/Downloads/CSV/scout_car.json", lines=True)

# %%
df.sample(20).T
# Out:
#                                                                            12401  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                              1.6 T SHT S&S Innovation Aut. 200
# body_type                                                                 Sedans
# price                                                                      28001
# vat                                                                         None
# km                                                                          - km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        147 kW
# Type                                                         [, New, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                       [\n2252812\n]
# First Registration                                                           NaN
# Body Color                                                                   NaN
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,441 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[6 l/100 km (comb)], [7 l/100 km (city)], [5 ...
# CO2 Emission                                                                 NaN
# Emission Class                                                               NaN
# \nComfort & Convenience\n                                                    NaN
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n                                                        NaN
# description                                                                   []
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5618   \
# url                            https://www.autoscout24.com//offers/audi-a3-sb...
# make_model                                                               Audi A3
# short_description              SB S line //LED/Navi/PDC *6 Jahre Qualitätsver...
# body_type                                                          Station wagon
# price                                                                      23475
# vat                                                               VAT deductible
# km                                                                         44 km
# registration                                                             02/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                      \n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                         [\n37205\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                              [\nIbisweiss\n]
# Upholstery                                                    [\nCloth, Other\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BLH\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,365 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.4 l/100 km (comb)], [5 l/100 km (city)], [...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Sport seat...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, S line Exterieurpaket ,  , Lufteinlassgit...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n6\n]
# Country version                                             [\nEuropean Union\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7295   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                      K 1.6 CDTI ST S&S Dynamic/Navi/AGR/LM 16"
# body_type                                                          Station wagon
# price                                                                      15400
# vat                                                               VAT deductible
# km                                                                     21,664 km
# registration                                                             03/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                           [, Employee's car, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n104 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                     [\nJB 251 JO\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Brown, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                        [\nKokosnuss Braun\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BHQ\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.9 l/100 km (comb)], [4.7 l/100 km (city)],...
# CO2 Emission                                           [\n104 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Roof rack, Sport seats, Touch s...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrzeug steht in 14913 Jüterbog, Dennewi...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5257   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                      SPB 30 TFSI S tronic Business - Pra.67113
# body_type                                                                 Sedans
# price                                                                      24600
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                             02/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                              [, Pre-registered, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                      \n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                      [\n57214760\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                    [\nCloth, Other\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.1 l/100 km (comb)], [5.8 l/100 km (city)],...
# CO2 Emission                                           [\n117 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n                                    [Navigation system]
# \nEntertainment & Media\n                      [Bluetooth, Hands-free equipment]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, I...
# description                    [\nPratica 67113, Airbag fullsize per conducen...
# Emission Label                                              [\n1 (No sticker)\n]
# Gears                                                                    [\n7\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            14035  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                      1.5 dCi 90ch energy Limited EDC 5p Euro6c
# body_type                                                                 Sedans
# price                                                                      17690
# vat                                                                         None
# km                                                                         10 km
# registration                                                             12/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         67 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                              [\nre74c1-FC-592-XH\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                   [\nGRIS\n]
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,461 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                                 NaN
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n                  [Bluetooth, On-board computer, Radio]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nMarque: RENAULTModèle: CLIOVersion: 1.5 dCi...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            12066  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                                   Station Wagon 1.6 136CV CDTi
# body_type                                                          Station wagon
# price                                                                      22000
# vat                                                               VAT deductible
# km                                                                     26,886 km
# registration                                                             04/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                           [, Employee's car, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                         [\n12 months\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                              [\nPart leather, Grey\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                                 NaN
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                                                                  NaN
# CO2 Emission                                                                 NaN
# Emission Class                                                      [[], [], []]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Digital radio, Hands-free equipmen...
# \nExtras\n                                          [Alloy wheels, Touch screen]
# \nSafety & Security\n          [ABS, Central door lock with remote control, D...
# description                    [\nVEICOLO USATO, POSSIBILITA’ DI FINANZIAMENT...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            9091   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                                             1.2i Black Edition
# body_type                                                                 Sedans
# price                                                                       8500
# vat                                                             Price negotiable
# km                                                                     34,000 km
# registration                                                             02/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         51 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2017, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,229 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,163 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.4 l/100 km (comb)], [6.7 l/100 km (city)],...
# CO2 Emission                                           [\n126 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Cruise control, Electrical side mirrors, Leat...
# \nEntertainment & Media\n                                                [Radio]
# \nExtras\n                                           [Alloy wheels, Sport seats]
# \nSafety & Security\n          [ABS, Central door lock with remote control, D...
# description                                                                   []
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            14866  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                                        IV (2) 0.9 TCE 75 TREND
# body_type                                                                 Sedans
# price                                                                      10880
# vat                                                                         None
# km                                                                         10 km
# registration                                                             05/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         56 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                       [\no5bhz7p\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                  [\nblanc\n]
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n898 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5 l/100 km (comb)], [6.3 l/100 km (city)], [...
# CO2 Emission                                           [\n113 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n                                       [Cruise control]
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Driver-side airbag, Electronic stability...
# description                    [\nIV (2) 0.9 TCE 75 TREND, essence, blanc, 29...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            11332  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                              1.6CDTI Innovation Automatik Navi
# body_type                                                                 Sedans
# price                                                                      20950
# vat                                                               VAT deductible
# km                                                                     25,550 km
# registration                                                             11/2017
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n114 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                   [\n00-50-12532\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                            [\nONYXSCHWARZ\n]
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n1844/AAD\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,673 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.3 l/100 km (comb)], [5.1 l/100 km (city)],...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                     [Alloy wheels, Cab or rented Car, Sport seats,...
# \nSafety & Security\n          [ABS, Adaptive headlights, Central door lock, ...
# description                    [\nFahrzeug-Nr: 00-50-12532,  ,  , Media,  , R...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            8756   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                                1.2 16v. 69 cv. 5 porte B-COLOR
# body_type                                                                Compact
# price                                                                       6900
# vat                                                               VAT deductible
# km                                                                     91,000 km
# registration                                                             02/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         51 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                [\n12 months\n, \n124 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                          [\n2795\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                   [\nNero\n]
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,229 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,163 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.3 l/100 km (comb)], [6.6 l/100 km (city)],...
# CO2 Emission                                           [\n124 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Leather steering wheel, Mul...
# \nEntertainment & Media\n                  [CD player, On-board computer, Radio]
# \nExtras\n                          [Alloy wheels, Sport package, Trailer hitch]
# \nSafety & Security\n          [ABS, Alarm system, Central door lock, Daytime...
# description                    [\nAuto in ottime condizioni sia di motore (km...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            6852   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                                      1.6 CDTi Dynamic (110 CV)
# body_type                                                                Compact
# price                                                                      12636
# vat                                                                         None
# km                                                                     23,176 km
# registration                                                             04/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                    [\n, \n, \n97 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# ...
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.4 l/100 km (comb)], [7.1 l/100 km (city)],...
# CO2 Emission                                           [\n124 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Alarm system, Central door lock, Daytime...
# description                    [\n, Sonderausstattung:, Allwetter-/ Ganzjahre...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            4803   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                             SPB Sportback 1.6 TDI 116 CV Sport
# body_type                                                                 Sedans
# price                                                                      21000
# vat                                                               VAT deductible
# km                                                                     23,900 km
# registration                                                             05/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                                [, Employee's car, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                      \n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                      [\n58178630\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                    [\nCloth, Other\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2 Emission                                           [\n106 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                      [Bluetooth, Hands-free equipment]
# \nExtras\n                         [Alloy wheels, Sport seats, Sport suspension]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, I...
# description                    [\n,  , Airbag fullsize per conducente e passe...
# Emission Label                                              [\n1 (No sticker)\n]
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            11048  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description              SP TOURER 1.6 CDTI 136CH ECOFLEX BUSINESS EDITION
# body_type                                                          Station wagon
# price                                                                      12990
# vat                                                               VAT deductible
# km                                                                     92,683 km
# registration                                                             04/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        101 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                          [\n6 months\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                          [\n1861\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                   [\nNOIR\n]
# Upholstery                                                                   NaN
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                                 NaN
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                        [[], [], []]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Daytime running lights, Driver-side airb...
# description                    [\n7 Haut parleurs ABS Accoudoir central AV Ai...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1161
# url                            https://www.autoscout24.com//offers/audi-a1-1-...
# make_model                                                               Audi A1
# short_description                                1.0 TFSI ultra Sportback design
# body_type                                                                 Sedans
# price                                                                      15300
# vat                                                               VAT deductible
# km                                                                     10,057 km
# registration                                                             01/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         60 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                 [\nYes\n, \n97 g CO2/km (comb)\n]
# Warranty                                                                     NaN
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                        [\n231059\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                           [\nCortinaweiss\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                                 NaN
# Model Code                                                        [\n0588/BHM\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,110 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[4.2 l/100 km (comb)], [5 l/100 km (city)], [...
# CO2 Emission                                            [\n97 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                           [Alloy wheels, Sport seats]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Audi Gebrauchtwagen :plus Garantie bis zu...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %% [markdown]
# ### * Drop the columns / rows determined unnecessary as a result of the analysis 💣 🧨

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %% [markdown]
# Lets see which columns has NaN values
# It shows us the percentage of NaN values, if it is not a significant column and if there are more than 40% NaN values, we need to drop them.

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 0.000000
# registration                       0.000000
# prev_owner                        42.892141
# kW                               100.000000
# hp                                 0.000000
# Type                               0.012564
# Previous Owners                   41.711163
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Warranty                          34.047365
# Full Service                      48.395000
# Non-smoking Vehicle               54.915510
# null                               0.000000
# Make                               0.000000
# Model                              0.000000
# Offer Number                      19.944720
# First Registration                10.032037
# Body Color                         3.750236
# Paint Type                        36.258559
# Body Color Original               23.613292
# Upholstery                        23.368302
# Body                               0.376908
# Nr. of Doors                       1.331742
# Nr. of Seats                       6.137320
# Model Code                        68.729192
# Gearing Type                       0.000000
# Displacement                       3.115774
# Cylinders                         35.680633
# Weight                            43.809285
# Drive chain                       43.080596
# Fuel                               0.000000
# Consumption                       11.973114
# CO2 Emission                      11.357497
# Emission Class                    18.977323
# \nComfort & Convenience\n          5.779257
# \nEntertainment & Media\n          8.631195
# \nExtras\n                        18.606696
# \nSafety & Security\n              6.168729
# description                        0.000000
# Emission Label                    74.967021
# Gears                             29.599849
# Country version                   52.346253
# Electricity consumption           99.139393
# Last Service Date                 96.444500
# Other Fuel Types                  94.472015
# Availability                      96.011056
# Last Timing Belt Service Date     99.899491
# Available from                    98.291350
# dtype: float64

# %%
df1 = df.copy()

# %%
df1.drop(['url','make_model','short_description','kW','registration','Previous Owners','Next Inspection','Inspection new','Full Service','null','Body Color Original','Body','Model Code','Weight','description','Emission Label','Country version','Electricity consumption','Last Service Date','Other Fuel Types','Availability','Last Timing Belt Service Date','Available from','Non-smoking Vehicle','Offer Number','Warranty'],axis = 1, inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   body_type                15859 non-null  object
#  1   price                    15919 non-null  int64
#  2   vat                      11406 non-null  object
#  3   km                       15919 non-null  object
#  4   prev_owner               9091 non-null   object
#  5   hp                       15919 non-null  object
#  6   Type                     15917 non-null  object
#  7   Make                     15919 non-null  object
#  8   Model                    15919 non-null  object
#  9   First Registration       14322 non-null  object
#  10  Body Color               15322 non-null  object
#  11  Paint Type               10147 non-null  object
#  12  Upholstery               12199 non-null  object
#  13  Nr. of Doors             15707 non-null  object
#  14  Nr. of Seats             14942 non-null  object
#  15  Gearing Type             15919 non-null  object
#  16  Displacement             15423 non-null  object
#  17  Cylinders                10239 non-null  object
#  18  Drive chain              9061 non-null   object
#  19  Fuel                     15919 non-null  object
#  20  Consumption              14013 non-null  object
#  21  CO2 Emission             14111 non-null  object
#  22  Emission Class           12898 non-null  object
#  23
# Comfort & Convenience
#   14999 non-null  object
#  24
# Entertainment & Media
#   14545 non-null  object
#  25
# Extras
#                  12957 non-null  object
#  26
# Safety & Security
#       14937 non-null  object
#  27  Gears                    11207 non-null  object
# dtypes: int64(1), object(27)
# memory usage: 3.4+ MB

# %% [markdown]
# ** We need to change some column name and values let's do it... 😎

# %%
df1.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %%
df3 = df.copy()

# %%
df3.km = df3.km.astype('str').replace('- km', np.nan)

# %%
df3.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914          NaN
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918          NaN
# Name: km, Length: 15919, dtype: object

# %%
df3.km = df3.km.str.strip(" km")

# %%
df3.km = df3.km.str.replace(",", "")

# %%
df3.km
# Out:
# 0        56013
# 1        80000
# 2        83450
# 3        73000
# 4        16200
#          ...
# 15914      NaN
# 15915     9900
# 15916       15
# 15917       10
# 15918      NaN
# Name: km, Length: 15919, dtype: object

# %%
df3.km = df3.km.astype(float)

# %%
df1.km = df3.km

# %%
df1['hp']
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: hp, Length: 15919, dtype: object

# %%
df1.rename(columns={'hp':'kw'}, inplace = True )

# %%
df3.kw
# Out:
# 0         66 kW
# 1        141 kW
# 2         85 kW
# 3         66 kW
# 4         66 kW
#           ...
# 15914    147 kW
# 15915    165 kW
# 15916    146 kW
# 15917    147 kW
# 15918    165 kW
# Name: kw, Length: 15919, dtype: object

# %%
df1.kw = df3.kw

# %%
df1.kw = df1.kw.str.strip(' kW')

# %%
df1.sample(3).T
# Out:
#                                                                        15840  \
# body_type                                                                Van
# price                                                                  46990
# vat                                                           VAT deductible
# km                                                                  3,500 km
# prev_owner                                                  1 previous owner
# hp                                                                    147 kW
# Type                        [, Demonstration, , Diesel (Particulate Filter)]
# Make                                                             \nRenault\n
# Model                                                       [\n, Espace, \n]
# First Registration                                            [\n, 2019, \n]
# Body Color                                                   [\n, Black, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nFull leather\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,997 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                              NaN
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# Consumption                [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2 Emission                                       [\n139 g CO2/km (comb)\n]
# Emission Class                                            [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, Digital radio, Hands-free equipmen...
# \nExtras\n                                      [Alloy wheels, Touch screen]
# \nSafety & Security\n      [ABS, Adaptive Cruise Control, Blind spot moni...
# Gears                                                                    NaN
#
#                                                                        4704   \
# body_type                                                             Sedans
# price                                                                  22490
# vat                                                           VAT deductible
# km                                                                 23,000 km
# prev_owner                                                  1 previous owner
# hp                                                                     85 kW
# Type                                                      [, Used, , Diesel]
# Make                                                                \nAudi\n
# Model                                                           [\n, A3, \n]
# First Registration                                            [\n, 2018, \n]
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                                        [\n, Diesel, \n]
# Consumption                [[3.7 l/100 km (comb)], [4 l/100 km (city)], [...
# CO2 Emission                                       [\n103 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, CD player, Digital radio, Hands-fr...
# \nExtras\n                 [Alloy wheels, Catalytic Converter, Sport pack...
# \nSafety & Security\n      [ABS, Adaptive headlights, Alarm system, Centr...
# Gears                                                                [\n7\n]
#
#                                                                        8285
# body_type                                                            Compact
# price                                                                  13663
# vat                                                           VAT deductible
# km                                                                     10 km
# prev_owner                                                              None
# hp                                                                     66 kW
# Type                                           [, New, , Regular/Benzine 91]
# Make                                                                \nOpel\n
# Model                                                        [\n, Corsa, \n]
# First Registration                                                       NaN
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                       [\nCloth\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                  [\n1,398 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                      [\nfront\n]
# Fuel                                            [\n, Regular/Benzine 91, \n]
# Consumption                [[6.3 l/100 km (comb)], [7.8 l/100 km (city)],...
# CO2 Emission                                       [\n143 g CO2/km (comb)\n]
# Emission Class                                            [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n  [Air conditioning, Cruise control, Heated stee...
# \nEntertainment & Media\n  [Bluetooth, CD player, On-board computer, Radi...
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                    NaN

# %%
df1.kw = df1.kw.replace(0,np.nan)

# %%
df1.kw = df1.kw.replace('-', np.nan)

# %%
df1.kw = df1.kw.astype(float)

# %%
df1.kw
# Out:
# 0         66.0
# 1        141.0
# 2         85.0
# 3         66.0
# 4         66.0
#          ...
# 15914    147.0
# 15915    165.0
# 15916    146.0
# 15917    147.0
# 15918    165.0
# Name: kw, Length: 15919, dtype: float64

# %%
df1.prev_owner = df1.prev_owner.str.strip(' previous owner')

# %%
df1.prev_owner.value_counts()
# Out:
# 1    8294
# 2     778
# 3      17
# 4       2
# Name: prev_owner, dtype: int64

# %%
df1.prev_owner = df1.prev_owner.astype(float)

# %%
df1.prev_owner
# Out:
# 0        2.0
# 1        NaN
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 15914    NaN
# 15915    1.0
# 15916    1.0
# 15917    NaN
# 15918    1.0
# Name: prev_owner, Length: 15919, dtype: float64

# %%
df2 = df1.copy()

# %%
df2.Make = df2.Make.str.strip('\n')

# %%
df1.Make = df2.Make

# %%
df1.Make
# Out:
# 0           Audi
# 1           Audi
# 2           Audi
# 3           Audi
# 4           Audi
#           ...
# 15914    Renault
# 15915    Renault
# 15916    Renault
# 15917    Renault
# 15918    Renault
# Name: Make, Length: 15919, dtype: object

# %%
df3.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
df3.Model=df3.Model.str[1].str.strip('\n')

# %%
df3.Model
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %%
df1.Model = df3.Model

# %%
df1.sample(3).T
# Out:
#                                                                  6145   \
# Body_Type                                                Station wagon
# Price                                                            10700
# Vat                                                               None
# Km                                                           78,840 km
# Previous_Owner                                        1 previous owner
# hp                                                               81 kW
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Astra
# Registration_Year                                               2016.0
# Body_Color                                                      Silver
# Paint_Type                                                \nMetallic\n
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n4\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[3.7 l/100 km (comb)], [3.9 l/100 km (city)],...
# CO2_Emission                                  [\n98 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Cruise control, El...
# Entertainment_Media  [Bluetooth, CD player, On-board computer, Radi...
# Extras                                                     [Roof rack]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
#
#                                                                  11370  \
# Body_Type                                                       Sedans
# Price                                                            21450
# Vat                                                     VAT deductible
# Km                                                           12,000 km
# Previous_Owner                                        1 previous owner
# hp                                                              121 kW
# Condition                                                         Used
# Make                                                              Opel
# Model                                                         Insignia
# Registration_Year                                               2017.0
# Body_Color                                                       Green
# Paint_Type                                                         NaN
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,490 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                                            [\n, Super E10 95, \n]
# Consumption          [[6.1 l/100 km (comb)], [7.5 l/100 km (city)],...
# CO2_Emission                                 [\n138 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, Hands-free equipment, On-board com...
# Extras               [Alloy wheels, Catalytic Converter, Touch scre...
# Safety_Security      [ABS, Adaptive Cruise Control, Central door lo...
# Gears                                                          [\n6\n]
#
#                                                                  13784
# Body_Type                                                       Sedans
# Price                                                             8500
# Vat                                                     VAT deductible
# Km                                                           59,073 km
# Previous_Owner                                        1 previous owner
# hp                                                               55 kW
# Condition                                                         Used
# Make                                                           Renault
# Model                                                             Clio
# Registration_Year                                               2016.0
# Body_Color                                                       Black
# Paint_Type                                                \nMetallic\n
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,461 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                                                  [\n, Diesel, \n]
# Consumption          [[3.6 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2_Emission                                  [\n85 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Electrical side mirrors, Po...
# Entertainment_Media  [Bluetooth, CD player, On-board computer, Radi...
# Extras                                                             NaN
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n5\n]

# %%
df3.Type = df1.Type.str[1]

# %%
df3.Type
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: Type, Length: 15919, dtype: object

# %%
df1.Type = df3.Type

# %%
df3.Type.value_counts()
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# Name: Type, dtype: int64

# %%
df1.rename(columns={'Type':'Condition'}, inplace = True)
df1.rename(columns={'body_type':'Body_Type'}, inplace = True)
df1.rename(columns={'price':'Price'}, inplace = True)
df1.rename(columns={'vat':'Vat'}, inplace = True)
df1.rename(columns={'prev_owner':'Previous_Owner'}, inplace = True)
df1.rename(columns={'First Registration':'Registration_Year'}, inplace = True)
df1.rename(columns={'Body Color':'Body_Color'}, inplace = True)
df1.rename(columns={'Paint Type':'Paint_Type'}, inplace = True)
df1.rename(columns={'Nr. of Doors':'Nr_of_Doors'}, inplace = True)
df1.rename(columns={'Nr. of Seats':'Nr_of_Seats'}, inplace = True)
df1.rename(columns={'Gearing Type':'Gearing_Type'}, inplace = True)
df1.rename(columns={'CO2 Emission':'CO2_Emission'}, inplace = True)
df1.rename(columns={'Emission Class':'Emission_Class'}, inplace = True)
df1.rename(columns={'\nComfort & Convenience\n':'Comfort_Convenience'}, inplace = True)
df1.rename(columns={'\nEntertainment & Media\n':'Entertainment_Media'}, inplace = True)
df1.rename(columns={'\nExtras\n':'Extras'}, inplace = True)
df1.rename(columns={'\nSafety & Security\n':'Safety & Security'}, inplace = True)
df1.rename(columns={'kw':'kW'}, inplace = True)
df1.rename(columns={'Safety & Security':'Safety_Security'}, inplace = True)
df1.rename(columns={'Drive chain':'Drive_Chain'}, inplace = True)
df1.rename(columns={'km':'Km'}, inplace = True)

# %%
df1.sample(3).T
# Out:
#                                                                  14632  \
# Body_Type                                                Station wagon
# Price                                                            10450
# Vat                                                     VAT deductible
# Km                                                           29,300 km
# Previous_Owner                                                    None
# hp                                                               66 kW
# Condition                                               Employee's car
# Make                                                           Renault
# Model                                                             Clio
# Registration_Year                                               2018.0
# Body_Color                                                        Grey
# Paint_Type                                                         NaN
# Upholstery                                                 [\nCloth\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,461 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[3.3 l/100 km (comb)], [3.7 l/100 km (city)],...
# CO2_Emission                                  [\n85 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Cruise control, Electrical ...
# Entertainment_Media    [Bluetooth, MP3, On-board computer, Radio, USB]
# Extras                                                     [Roof rack]
# Safety_Security      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                          [\n5\n]
#
#                                                                  6281   \
# Body_Type                                                Station wagon
# Price                                                             9950
# Vat                                                     VAT deductible
# Km                                                          111,283 km
# Previous_Owner                                        1 previous owner
# hp                                                              100 kW
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Astra
# Registration_Year                                               2016.0
# Body_Color                                                       White
# Paint_Type                                                \nMetallic\n
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n4\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[3.9 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2_Emission                                 [\n103 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                                       [Alloy wheels, Roof rack]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
#
#                                                                  14239
# Body_Type                                                       Sedans
# Price                                                             9700
# Vat                                                               None
# Km                                                           43,000 km
# Previous_Owner                                                    None
# hp                                                               55 kW
# Condition                                                         Used
# Make                                                           Renault
# Model                                                             Clio
# Registration_Year                                               2017.0
# Body_Color                                                       White
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,461 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[3.3 l/100 km (comb)], [3.5 l/100 km (city)],...
# CO2_Emission                                  [\n85 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Cruise control, Electrical side mirrors, Hill...
# Entertainment_Media         [Bluetooth, On-board computer, Radio, USB]
# Extras                                                             NaN
# Safety_Security      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                          [\n5\n]

# %%
df1.Registration_Year = df1.Registration_Year.str[1].astype(float)

# %%
df1.Registration_Year
# Out:
# 0        2016.0
# 1        2017.0
# 2        2016.0
# 3        2016.0
# 4        2016.0
#           ...
# 15914       NaN
# 15915    2019.0
# 15916    2019.0
# 15917    2019.0
# 15918    2019.0
# Name: Registration_Year, Length: 15919, dtype: float64

# %%
df1.Body_Color
# Out:
# 0        [\n, Black, \n]
# 1          [\n, Red, \n]
# 2        [\n, Black, \n]
# 3        [\n, Brown, \n]
# 4        [\n, Black, \n]
#               ...
# 15914     [\n, Grey, \n]
# 15915     [\n, Grey, \n]
# 15916    [\n, White, \n]
# 15917     [\n, Grey, \n]
# 15918     [\n, Grey, \n]
# Name: Body_Color, Length: 15919, dtype: object

# %%
df1.Body_Color = df1.Body_Color.str[1]

# %%
df1.Body_Color
# Out:
# 0        Black
# 1          Red
# 2        Black
# 3        Brown
# 4        Black
#          ...
# 15914     Grey
# 15915     Grey
# 15916    White
# 15917     Grey
# 15918     Grey
# Name: Body_Color, Length: 15919, dtype: object

# %%
df1["Upholstery"]
# Out:
# 0               [\nCloth, Black\n]
# 1                [\nCloth, Grey\n]
# 2               [\nCloth, Black\n]
# 3                              NaN
# 4               [\nCloth, Black\n]
#                    ...
# 15914                          NaN
# 15915                  [\nCloth\n]
# 15916    [\nFull leather, Black\n]
# 15917           [\nPart leather\n]
# 15918    [\nFull leather, Brown\n]
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1["Upholstery"] = df1["Upholstery"].str[0].str.strip('\n')

# %%
df1["Upholstery"]
# Out:
# 0               Cloth, Black
# 1                Cloth, Grey
# 2               Cloth, Black
# 3                        NaN
# 4               Cloth, Black
#                 ...
# 15914                    NaN
# 15915                  Cloth
# 15916    Full leather, Black
# 15917           Part leather
# 15918    Full leather, Brown
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1.Paint_Type = df1.Paint_Type.str.strip('\n')

# %%
df1.Paint_Type
# Out:
# 0        Metallic
# 1             NaN
# 2        Metallic
# 3        Metallic
# 4        Metallic
#            ...
# 15914    Metallic
# 15915    Metallic
# 15916         NaN
# 15917         NaN
# 15918    Metallic
# Name: Paint_Type, Length: 15919, dtype: object

# %%
df1.sample(3).T
# Out:
#                                                                  14786  \
# Body_Type                                                       Sedans
# Price                                                            10990
# Vat                                                     VAT deductible
# Km                                                                1 km
# Previous_Owner                                                    None
# hp                                                               55 kW
# Condition                                               Pre-registered
# Make                                                           Renault
# Model                                                             Clio
# Registration_Year                                               2019.0
# Body_Color                                                        Grey
# Paint_Type                                                    Metallic
# Upholstery                                                 Cloth, Grey
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                              [\n898 cc\n]
# Cylinders                                                      [\n3\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                                                [\n, Gasoline, \n]
# Consumption          [[5 l/100 km (comb)], [6.3 l/100 km (city)], [...
# CO2_Emission                                 [\n113 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Cruise control, Electrical side mirrors, Hill...
# Entertainment_Media               [MP3, On-board computer, Radio, USB]
# Extras                                                             NaN
# Safety_Security      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                          [\n5\n]
#
#                                                                  9706   \
# Body_Type                                                      Compact
# Price                                                            14213
# Vat                                                     VAT deductible
# Km                                                               10 km
# Previous_Owner                                                    None
# hp                                                               66 kW
# Condition                                                          New
# Make                                                              Opel
# Model                                                            Corsa
# Registration_Year                                                  NaN
# Body_Color                                                        Blue
# Paint_Type                                                    Metallic
# Upholstery                                                       Cloth
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,398 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                                      [\n, Regular/Benzine 91, \n]
# Consumption          [[6.3 l/100 km (comb)], [7.8 l/100 km (city)],...
# CO2_Emission                                 [\n143 g CO2/km (comb)\n]
# Emission_Class                                      [\nEuro 6d-TEMP\n]
# Comfort_Convenience  [Air conditioning, Cruise control, Electrical ...
# Entertainment_Media  [Bluetooth, Hands-free equipment, On-board com...
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
#
#                                                                  11704
# Body_Type                                                       Sedans
# Price                                                            18450
# Vat                                                     VAT deductible
# Km                                                           23,624 km
# Previous_Owner                                        1 previous owner
# hp                                                              103 kW
# Condition                                               Employee's car
# Make                                                              Opel
# Model                                                         Insignia
# Registration_Year                                               2018.0
# Body_Color                                                      Silver
# Paint_Type                                                    Metallic
# Upholstery                                         Full leather, Black
# Nr_of_Doors                                                    [\n4\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,490 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                                                [\n, Super 95, \n]
# Consumption          [[5.7 l/100 km (comb)], [7.3 l/100 km (city)],...
# CO2_Emission                                 [\n130 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras               [Alloy wheels, Ski bag, Sport seats, Touch scr...
# Safety_Security      [ABS, Adaptive Cruise Control, Adaptive headli...
# Gears                                                              NaN

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.str.strip('\n')

# %%
df1.Nr_of_Doors
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: Nr_of_Doors, Length: 15919, dtype: object

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.apply(lambda item: item[0] if type(item) == list else item)

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.str.strip('\n')

# %%
df1.Nr_of_Seats
# Out:
# 0        5
# 1        4
# 2        4
# 3        4
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    7
# 15917    7
# 15918    5
# Name: Nr_of_Seats, Length: 15919, dtype: object
