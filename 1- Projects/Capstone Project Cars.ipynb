# %% [markdown]
# ###                               Exploratory Data Analysis (EDA) Project   🏸🧪💻🚀👩‍💻

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_json("C:/Users/rusla/Downloads/CSV/scout_car.json", lines=True)

# %%
df.sample(20).T
# Out:
#                                                                            3545   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                     Sportback 1.6 TDI Sport PDC+ SHZ Klimaauto
# body_type                                                                 Sedans
# price                                                                      15980
# vat                                                               VAT deductible
# km                                                                    110,712 km
# registration                                                             03/2017
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                            [\n03/2020\n, \n99 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                        [\nA94863\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                        [\nbrillantschwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/AYB\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                            [\n99 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                [CD player, MP3, Radio]
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrzeug-Nummer: A94863,  , Bi-Xenon,  , ...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            15774  \
# url                            https://www.autoscout24.com//offers/renault-es...
# make_model                                                        Renault Espace
# short_description                Blue dCi 200CV EDC Executive 4Control rif.FV976
# body_type                                                                    Van
# price                                                                      35900
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                             02/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        147 kW
# Type                                                [, Employee's car, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                [\n24 months\n, \n139 g CO2/km (comb)\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                           [\n, Espace, \n]
# Offer Number                                                       [\n2644457\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                 [\nGrigio\n]
# Upholstery                                             [\nFull leather, Beige\n]
# Body                                                               [\n, Van, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,997 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,758 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2 Emission                                           [\n139 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                 [Bluetooth, Digital radio, Radio, USB]
# \nExtras\n                                          [Alloy wheels, Touch screen]
# \nSafety & Security\n          [ABS, Blind spot monitor, Driver-side airbag, ...
# description                    [\nDEK:[2644457], VETTURA DISPONIBILE PRESSO I...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            14122  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                                      Life TCe 75 Komfort-Paket
# body_type                                                                Compact
# price                                                                       9900
# vat                                                               VAT deductible
# km                                                                        150 km
# registration                                                             03/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         56 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n03/2022\n, \n113 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                     [\ngw_nr_819\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                      [\nArktis-Weiß (369)\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n3333/BAJ\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n898 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5 l/100 km (comb)], [6.3 l/100 km (city)], [...
# CO2 Emission                                           [\n113 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Cruise control, Electrical side mirrors, Hill...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nTAGESZULASSUNG - DEUTSCHES FAHRZEUG, inkl. ...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7908   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                             1.6 CDTi S/S 100kW (136CV) Dynamic
# body_type                                                                Compact
# price                                                                      16900
# vat                                                                         None
# km                                                                     10,182 km
# registration                                                             01/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                        [\n365203\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                             [\nNegro Mineral (metalizado)\n]
# Upholstery                                                                   NaN
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                                 NaN
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                                 NaN
# Emission Class                                                               NaN
# \nComfort & Convenience\n                                                    NaN
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n                                                        NaN
# description                                                                   []
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            8535   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description               1.4 90CV Aut. 5P Advance , AUTO - CERCHI IN LEGA
# body_type                                                                 Sedans
# price                                                                      11900
# vat                                                                         None
# km                                                                     17,900 km
# registration                                                             03/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                      \n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                       [\n2678659\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                 [\nBianco\n]
# Upholstery                                                           [\nCloth\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,088 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[4.7 l/100 km (comb)], [5.8 l/100 km (city)],...
# CO2 Emission                                           [\n110 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Electrical side mirrors, Po...
# \nEntertainment & Media\n                     [Bluetooth, CD player, Radio, USB]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\nDEK:[2678659], RIF: 1133218P, Opel Corsa 1....
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            11366  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                   Grand Sport 1.6 CDTI Edition GPS PTS 1° MAIN
# body_type                                                                 Sedans
# price                                                                      21480
# vat                                                               VAT deductible
# km                                                                     27,000 km
# registration                                                             02/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                   [\n, \n, \n134 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                          [\n5912\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,440 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[5.1 l/100 km (comb)], [6.1 l/100 km (city)],...
# CO2 Emission                                           [\n134 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n        [Bluetooth, MP3, On-board computer, Radio, USB]
# \nExtras\n                                          [Alloy wheels, Touch screen]
# \nSafety & Security\n          [ABS, Central door lock with remote control, D...
# description                    [\n, 1° Main, Boîte automatique, Climatisation...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                    [\nBelgium\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            3781   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                               SPB 1.6 TDI 116CV S tronic Sport
# body_type                                                                 Sedans
# price                                                                      21900
# vat                                                               VAT deductible
# km                                                                     31,032 km
# registration                                                             03/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n103 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                       [\n2489959\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                     [\nGrigio Monsone Met\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,285 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[3.9 l/100 km (comb)], [4.1 l/100 km (city)],...
# CO2 Emission                                           [\n103 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Multi-function steering whe...
# \nEntertainment & Media\n                                     [Bluetooth, Radio]
# \nExtras\n                                           [Alloy wheels, Sport seats]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\nDEK:[2489959], Cod. 23998-U , Vettura prove...
# Emission Label                                                               NaN
# Gears                                                                    [\n7\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            10951  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                        GS 1.6 CDTi 100kW S&S Turbo D Selective
# body_type                                                                 Sedans
# price                                                                      14290
# vat                                                               VAT deductible
# km                                                                     34,780 km
# registration                                                             06/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        101 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                      \n03/2019\n
# Inspection new                                                               NaN
# Warranty                                                         [\n12 months\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2017, \n]
# Body Color                                                       [\n, Brown, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                 [\nMarrón\n]
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,503 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4.3 l/100 km (comb)], [5.1 l/100 km (city)],...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                       [Bluetooth, USB]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n                     [Electronic stability control, Isofix]
# description                    [\nClicars | El 95% de Nuestros Clientes nos V...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                         [\n06/2017\n, \n114 g CO2/km (comb)\n]
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5950   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                                      1.6 Cdti 136cv Innovation
# body_type                                                                 Sedans
# price                                                                      12900
# vat                                                               VAT deductible
# km                                                                     45,537 km
# registration                                                             10/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                [\n36 months\n, \n115 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                       [\n5594252\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                              [\nCARBON FLASH MET (G) (zwa\n]
# Upholstery                                             [\nPart leather, Other\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,900 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4.4 l/100 km (comb)], [5.5 l/100 km (city)],...
# CO2 Emission                                           [\n115 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                                         [Alloy wheels, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\nRif. 5594252 - VEICOLO FATTURABILE - Vettur...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            10841  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description              ST 1.6 CDTI Edition Automatik EURO 6 Navi Keyless
# body_type                                                          Station wagon
# price                                                                       9980
# vat                                                               VAT deductible
# km                                                                    155,000 km
# registration                                                             02/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n135 g CO2/km (comb)\n]
# Warranty                                                                     NaN
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                          [\n9168\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nargon silber\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BFI\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                                      [[5.1 l/100 km (comb)], [], []]
# CO2 Emission                                           [\n135 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                       [Catalytic Converter, Roof rack, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, FINANZIERUNG ZU BESTEN KONDITIONEN - SCHN...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5256   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                                  SPB 30 TFSI S tronic Business
# body_type                                                                 Sedans
# price                                                                      24800
# vat                                                                         None
# km                                                                         37 km
# registration                                                             02/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                              [, Pre-registered, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# ...
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,275 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                     [\n, Gasoline (Particulate Filter), \n]
# Consumption                    [[5.1 l/100 km (comb)], [5.8 l/100 km (city)],...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Digital radio, Hands-fr...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Sport pack...
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Central door lo...
# description                    [\nAUDI A3 1.0 SPB 116CV S TRONIC SPORT , ANNO...
# Emission Label                                                               NaN
# Gears                                                                    [\n7\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            4457   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                                    SPB 1.6 TDI 116 CV Business
# body_type                                                                 Sedans
# price                                                                      19900
# vat                                                               VAT deductible
# km                                                                     30,000 km
# registration                                                             02/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                                [, Employee's car, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n106 g CO2/km (comb)\n]
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                       [\n1601171\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                 [\nBianco\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,230 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2 Emission                                           [\n106 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                  [Bluetooth, On-board computer, Radio]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\nDEK:[1601171], Codice vettura 53196-N, Vett...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            4701   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                       Sportback sport,Automatik,Navi,Xenon,APS
# body_type                                                          Station wagon
# price                                                                      22490
# vat                                                                         None
# km                                                                     25,600 km
# registration                                                             10/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n10/2021\n, \n109 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2018, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                 [\nFlorettsilber Metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BLH\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.1 l/100 km (comb)], [4.4 l/100 km (city)],...
# CO2 Emission                                           [\n109 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                     [Alloy wheels, Sport package, Sport seats, Spo...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Sonderausstattung:, Audi connect (Interne...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            13149
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                                  IV BUSINESS dCi 90 Energy EDC
# body_type                                                                 Sedans
# price                                                                      15490
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                             06/2018
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                      [\nVO008680\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                [\nplatine\n]
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,461 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,717 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                                      [[3.5 l/100 km (comb)], [], []]
# CO2 Emission                                            [\n92 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n                                       [Cruise control]
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Driver-side airbag, Electronic stability...
# description                    [\nIV BUSINESS dCi 90 Energy EDC, diesel, plat...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %% [markdown]
#  🛑 Drop the columns / rows determined unnecessary as a result of the analysis 💣 🧨

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %% [markdown]
#  🛑 Lets see which columns has NaN values
# It shows us the percentage of NaN values, if it is not a significant column and if there are more than 40% NaN values, we need to drop them.

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 0.000000
# registration                       0.000000
# prev_owner                        42.892141
# kW                               100.000000
# hp                                 0.000000
# Type                               0.012564
# Previous Owners                   41.711163
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Warranty                          34.047365
# Full Service                      48.395000
# Non-smoking Vehicle               54.915510
# null                               0.000000
# Make                               0.000000
# Model                              0.000000
# Offer Number                      19.944720
# First Registration                10.032037
# Body Color                         3.750236
# Paint Type                        36.258559
# Body Color Original               23.613292
# Upholstery                        23.368302
# Body                               0.376908
# Nr. of Doors                       1.331742
# Nr. of Seats                       6.137320
# Model Code                        68.729192
# Gearing Type                       0.000000
# Displacement                       3.115774
# Cylinders                         35.680633
# Weight                            43.809285
# Drive chain                       43.080596
# Fuel                               0.000000
# Consumption                       11.973114
# CO2 Emission                      11.357497
# Emission Class                    18.977323
# \nComfort & Convenience\n          5.779257
# \nEntertainment & Media\n          8.631195
# \nExtras\n                        18.606696
# \nSafety & Security\n              6.168729
# description                        0.000000
# Emission Label                    74.967021
# Gears                             29.599849
# Country version                   52.346253
# Electricity consumption           99.139393
# Last Service Date                 96.444500
# Other Fuel Types                  94.472015
# Availability                      96.011056
# Last Timing Belt Service Date     99.899491
# Available from                    98.291350
# dtype: float64

# %%
df1 = df.copy()

# %%
df1.drop(['url','make_model','short_description','kW','registration','Previous Owners','Next Inspection','Inspection new','Full Service','null','Body Color Original','Body','Model Code','Weight','description','Emission Label','Country version','Electricity consumption','Last Service Date','Other Fuel Types','Availability','Last Timing Belt Service Date','Available from','Non-smoking Vehicle','Offer Number','Warranty'],axis = 1, inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   body_type                15859 non-null  object
#  1   price                    15919 non-null  int64
#  2   vat                      11406 non-null  object
#  3   km                       15919 non-null  object
#  4   prev_owner               9091 non-null   object
#  5   hp                       15919 non-null  object
#  6   Type                     15917 non-null  object
#  7   Make                     15919 non-null  object
#  8   Model                    15919 non-null  object
#  9   First Registration       14322 non-null  object
#  10  Body Color               15322 non-null  object
#  11  Paint Type               10147 non-null  object
#  12  Upholstery               12199 non-null  object
#  13  Nr. of Doors             15707 non-null  object
#  14  Nr. of Seats             14942 non-null  object
#  15  Gearing Type             15919 non-null  object
#  16  Displacement             15423 non-null  object
#  17  Cylinders                10239 non-null  object
#  18  Drive chain              9061 non-null   object
#  19  Fuel                     15919 non-null  object
#  20  Consumption              14013 non-null  object
#  21  CO2 Emission             14111 non-null  object
#  22  Emission Class           12898 non-null  object
#  23
# Comfort & Convenience
#   14999 non-null  object
#  24
# Entertainment & Media
#   14545 non-null  object
#  25
# Extras
#                  12957 non-null  object
#  26
# Safety & Security
#       14937 non-null  object
#  27  Gears                    11207 non-null  object
# dtypes: int64(1), object(27)
# memory usage: 3.4+ MB

# %% [markdown]
# 🛑 We need to change some column name and values let's do it... 😎

# %%
df1.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %%
df1.km = df1.km.astype('str').replace('- km', np.nan)
df1.km = df1.km.str.replace(",", "")

# %%
df1.km
# Out:
# 0        56013 km
# 1        80000 km
# 2        83450 km
# 3        73000 km
# 4        16200 km
#            ...
# 15914         nan
# 15915     9900 km
# 15916       15 km
# 15917       10 km
# 15918         nan
# Name: km, Length: 15919, dtype: object

# %%
df1.km = df1.km.str.strip(" km")

# %%
df1.km
# Out:
# 0        56013
# 1        80000
# 2        83450
# 3        73000
# 4        16200
#          ...
# 15914      nan
# 15915     9900
# 15916       15
# 15917       10
# 15918      nan
# Name: km, Length: 15919, dtype: object

# %%
df1.km = df1.km.astype(float)

# %%
df1.km
# Out:
# 0        56013.0
# 1        80000.0
# 2        83450.0
# 3        73000.0
# 4        16200.0
#           ...
# 15914        NaN
# 15915     9900.0
# 15916       15.0
# 15917       10.0
# 15918        NaN
# Name: km, Length: 15919, dtype: float64

# %%
df1.rename(columns={'hp':'kw'}, inplace = True )

# %%
df1.kw
# Out:
# 0         66
# 1        141
# 2         85
# 3         66
# 4         66
#          ...
# 15914    147
# 15915    165
# 15916    146
# 15917    147
# 15918    165
# Name: kw, Length: 15919, dtype: object

# %%
df1.kw = df1.kw.str.strip('kW')

# %%
df1.sample(3).T
# Out:
#                                                                         4442  \
# body_type                                                             Sedans
# price                                                                  19950
# vat                                                           VAT deductible
# km                                                                   21592.0
# prev_owner                                                  1 previous owner
# kw                                                                       85
# Type                       [, Employee's car, , Diesel (Particulate Filter)]
# Make                                                                \nAudi\n
# Model                                                           [\n, A3, \n]
# First Registration                                            [\n, 2018, \n]
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                         [\nPart leather, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# Consumption                [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# CO2 Emission                                       [\n108 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n  [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                [\n6\n]
#
#                                                                         7365  \
# body_type                                                      Station wagon
# price                                                                  14950
# vat                                                           VAT deductible
# km                                                                   15200.0
# prev_owner                                                  1 previous owner
# kw                                                                      100
# Type                                            [, Employee's car, , Diesel]
# Make                                                                \nOpel\n
# Model                                                        [\n, Astra, \n]
# First Registration                                            [\n, 2018, \n]
# Body Color                                                  [\n, Silver, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                         [\nPart leather, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                                        [\n, Diesel, \n]
# Consumption                [[4.6 l/100 km (comb)], [5.5 l/100 km (city)],...
# CO2 Emission                                       [\n121 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                       [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n      [ABS, Central door lock, Central door lock wit...
# Gears                                                                [\n6\n]
#
#                                                                         4939
# body_type                                                             Sedans
# price                                                                  20830
# vat                                                           VAT deductible
# km                                                                   21851.0
# prev_owner                                                 2 previous owners
# kw                                                                       85
# Type                                           [, Demonstration, , Super 95]
# Make                                                                \nAudi\n
# Model                                                           [\n, A3, \n]
# First Registration                                            [\n, 2018, \n]
# Body Color                                                   [\n, Black, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                [\nCloth, Black\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                    [\n999 cc\n]
# Cylinders                                                            [\n3\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                                      [\n, Super 95, \n]
# Consumption                [[4.7 l/100 km (comb)], [5.7 l/100 km (city)],...
# CO2 Emission                                       [\n108 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n  [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                 [Alloy wheels, Catalytic Converter, Roof rack,...
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                [\n6\n]

# %%
df1.kw = df1.kw.replace(0,np.nan)

# %%
df1.kw = df1.kw.replace('-',np.nan)

# %%
df1['kw']= df1.kw.astype(float)
df1.kw
# Out:
# 0         66.0
# 1        141.0
# 2         85.0
# 3         66.0
# 4         66.0
#          ...
# 15914    147.0
# 15915    165.0
# 15916    146.0
# 15917    147.0
# 15918    165.0
# Name: kw, Length: 15919, dtype: float64

# %%
df1.prev_owner = df1.prev_owner.str.strip(' previous owner')

# %%
df1.prev_owner = df1.prev_owner.astype(float)

# %%
df1.prev_owner
# Out:
# 0        2.0
# 1        NaN
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 15914    NaN
# 15915    1.0
# 15916    1.0
# 15917    NaN
# 15918    1.0
# Name: prev_owner, Length: 15919, dtype: float64

# %%
df2 = df1.copy()

# %%
df2.Make = df2.Make.str.strip('\n')

# %%
df1.Make = df2.Make

# %%
df1.Make
# Out:
# 0           Audi
# 1           Audi
# 2           Audi
# 3           Audi
# 4           Audi
#           ...
# 15914    Renault
# 15915    Renault
# 15916    Renault
# 15917    Renault
# 15918    Renault
# Name: Make, Length: 15919, dtype: object

# %%
df2.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
df2.Model=df2.Model.str[1].str.strip('\n')

# %%
df2.Model
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %%
df1.Model = df2.Model

# %%
df1.sample(3).T
# Out:
#                                                                        14674  \
# body_type                                                            Compact
# price                                                                  11380
# vat                                                           VAT deductible
# km                                                                      10.0
# prev_owner                                                               NaN
# kw                                                                       57
# Type                                                    [, Used, , Gasoline]
# Make                                                                 Renault
# Model                                                                   Clio
# First Registration                                            [\n, 2019, \n]
# Body Color                                                    [\n, Grey, \n]
# Paint Type                                                               NaN
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                             NaN
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                    [\n898 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                              NaN
# Fuel                                                      [\n, Gasoline, \n]
# Consumption                                                              NaN
# CO2 Emission                                                    [[], [], []]
# Emission Class                                                           NaN
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n  [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                                               NaN
# \nSafety & Security\n      [ABS, Daytime running lights, Driver-side airb...
# Gears                                                                    NaN
#
#                                                                        1974   \
# body_type                                                             Sedans
# price                                                                  27796
# vat                                                                     None
# km                                                                       NaN
# prev_owner                                                               NaN
# kw                                                                       85
# Type                                                     [, New, , Gasoline]
# Make                                                                    Audi
# Model                                                                     A1
# First Registration                                                       NaN
# Body Color                                                   [\n, White, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                       [\nBlack\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n4\n]
# Gearing Type                                             [\n, Automatic, \n]
# Displacement                                                    [\n999 cc\n]
# Cylinders                                                            [\n3\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                                      [\n, Gasoline, \n]
# Consumption                [[4.8 l/100 km (comb)], [5.8 l/100 km (city)],...
# CO2 Emission                                       [\n108 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Electrical side mirrors, Le...
# \nEntertainment & Media\n                            [Bluetooth, Radio, USB]
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [ABS, Central door lock, Driver-side airbag, E...
# Gears                                                                [\n7\n]
#
#                                                                        8684
# body_type                                                            Compact
# price                                                                   7450
# vat                                                           VAT deductible
# km                                                                   99950.0
# prev_owner                                                               NaN
# kw                                                                       70
# Type                                 [, Used, , Diesel (Particulate Filter)]
# Make                                                                    Opel
# Model                                                                  Corsa
# First Registration                                            [\n, 2016, \n]
# Body Color                                                    [\n, Blue, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                        [\nGrey\n]
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,248 cc\n]
# Cylinders                                                            [\n4\n]
# Drive chain                                                      [\nfront\n]
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# Consumption                [[3.8 l/100 km (comb)], [4.5 l/100 km (city)],...
# CO2 Emission                                       [\n100 g CO2/km (comb)\n]
# Emission Class                                                  [\nEuro 6\n]
# \nComfort & Convenience\n  [Air conditioning, Cruise control, Hill Holder...
# \nEntertainment & Media\n              [Bluetooth, On-board computer, Radio]
# \nExtras\n                                                               NaN
# \nSafety & Security\n      [ABS, Central door lock, Daytime running light...
# Gears                                                                [\n6\n]

# %%
df2.Type = df1.Type.str[1]

# %%
df2.Type
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: Type, Length: 15919, dtype: object

# %%
df1.Type = df2.Type

# %%
df1.Type.value_counts(dropna = False)
# Out:
# Used              11096
# New                1650
# Pre-registered     1364
# Employee's car     1011
# Demonstration       796
# NaN                   2
# Name: Type, dtype: int64

# %% [markdown]
# 🎯 Lets change the column names

# %%
df1.rename(columns={'Type':'Condition'}, inplace = True)
df1.rename(columns={'body_type':'Body_Type'}, inplace = True)
df1.rename(columns={'price':'Price'}, inplace = True)
df1.rename(columns={'vat':'Vat'}, inplace = True)
df1.rename(columns={'prev_owner':'Previous_Owner'}, inplace = True)
df1.rename(columns={'First Registration':'Registration_Year'}, inplace = True)
df1.rename(columns={'Body Color':'Body_Color'}, inplace = True)
df1.rename(columns={'Paint Type':'Paint_Type'}, inplace = True)
df1.rename(columns={'Nr. of Doors':'Nr_of_Doors'}, inplace = True)
df1.rename(columns={'Nr. of Seats':'Nr_of_Seats'}, inplace = True)
df1.rename(columns={'Gearing Type':'Gearing_Type'}, inplace = True)
df1.rename(columns={'CO2 Emission':'CO2_Emission'}, inplace = True)
df1.rename(columns={'Emission Class':'Emission_Class'}, inplace = True)
df1.rename(columns={'\nComfort & Convenience\n':'Comfort_Convenience'}, inplace = True)
df1.rename(columns={'\nEntertainment & Media\n':'Entertainment_Media'}, inplace = True)
df1.rename(columns={'\nExtras\n':'Extras'}, inplace = True)
df1.rename(columns={'\nSafety & Security\n':'Safety & Security'}, inplace = True)
df1.rename(columns={'kw':'kW'}, inplace = True)
df1.rename(columns={'Safety & Security':'Safety_Security'}, inplace = True)
df1.rename(columns={'Drive chain':'Drive_Chain'}, inplace = True)
df1.rename(columns={'km':'Km'}, inplace = True)

# %% [markdown]
# 🛑 I prefer "First Registration" column because I don't need month values

# %%
df1.Registration_Year = df1.Registration_Year.str[1].astype(float)

# %%
df1.Registration_Year
# Out:
# 0        2016.0
# 1        2017.0
# 2        2016.0
# 3        2016.0
# 4        2016.0
#           ...
# 15914       NaN
# 15915    2019.0
# 15916    2019.0
# 15917    2019.0
# 15918    2019.0
# Name: Registration_Year, Length: 15919, dtype: float64

# %%
df1.Body_Color
# Out:
# 0        [\n, Black, \n]
# 1          [\n, Red, \n]
# 2        [\n, Black, \n]
# 3        [\n, Brown, \n]
# 4        [\n, Black, \n]
#               ...
# 15914     [\n, Grey, \n]
# 15915     [\n, Grey, \n]
# 15916    [\n, White, \n]
# 15917     [\n, Grey, \n]
# 15918     [\n, Grey, \n]
# Name: Body_Color, Length: 15919, dtype: object

# %%
df1.Body_Color = df1.Body_Color.str[1]

# %%
df1.Body_Color
# Out:
# 0        Black
# 1          Red
# 2        Black
# 3        Brown
# 4        Black
#          ...
# 15914     Grey
# 15915     Grey
# 15916    White
# 15917     Grey
# 15918     Grey
# Name: Body_Color, Length: 15919, dtype: object

# %%
df1["Upholstery"]
# Out:
# 0               [\nCloth, Black\n]
# 1                [\nCloth, Grey\n]
# 2               [\nCloth, Black\n]
# 3                              NaN
# 4               [\nCloth, Black\n]
#                    ...
# 15914                          NaN
# 15915                  [\nCloth\n]
# 15916    [\nFull leather, Black\n]
# 15917           [\nPart leather\n]
# 15918    [\nFull leather, Brown\n]
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1["Upholstery"] = df1["Upholstery"].str[0].str.strip('\n')

# %%
df1["Upholstery"]
# Out:
# 0               Cloth, Black
# 1                Cloth, Grey
# 2               Cloth, Black
# 3                        NaN
# 4               Cloth, Black
#                 ...
# 15914                    NaN
# 15915                  Cloth
# 15916    Full leather, Black
# 15917           Part leather
# 15918    Full leather, Brown
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1['Paint_Type'].value_counts(dropna = False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.map_locations()
#
# TypeError: unhashable type: 'list'
# Exception ignored in: 'pandas._libs.index.IndexEngine._call_map_locations'
# Traceback (most recent call last):
#   File "pandas\_libs\hashtable_class_helper.pxi", line 4588, in pandas._libs.hashtable.PyObjectHashTable.map_locations
# TypeError: unhashable type: 'list'
# [\nMetallic\n]       9794
# NaN                  5772
# [\nUni/basic\n]       347
# [\nPerl effect\n]       6
# Name: Paint_Type, dtype: int64
