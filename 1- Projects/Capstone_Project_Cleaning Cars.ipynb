# %% [markdown]
# # Capstone Project

# %% [markdown]
# ## EDA for Car Price Prediction Model

# %% [markdown]
# >In this project we are going to be cleaning and analyzing a file for a car price prediction model.

# %% [markdown]
# - Before start analyzing first let's import the libraries we might use for further steps.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %% [markdown]
# - - -

# %% [markdown]
# <img src="readme.png" style="height:1000px">

# %% [markdown]
# <br>

# %% [markdown]
# - Right after importing the libraries, I am going to read the json file that I am going to be working on.

# %% [markdown]
# <br>

# %%
df = pd.read_json("scout_car.json", lines=True)

# %% [markdown]
# <br>

# %% [markdown]
# - To get an idea of what the data looks like, let's have a look at that by getting some random samples.
# - I am going to get the tranpose of it to see all the columns.

# %% [markdown]
# <br>

# %%
df.sample(20).T
# Out:
#                                                                            14097  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                                   1.2 16V 75 Life Cool & Sound
# body_type                                                                 Sedans
# price                                                                       9824
# vat                                                               VAT deductible
# km                                                                     23,000 km
# registration                                                             02/2017
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         55 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                         [\n12 months\n]
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                          [\n49f6ef77-f517-4754-8405-8c51cde65f74\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,149 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,059 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.6 l/100 km (comb)], [7.2 l/100 km (city)],...
# CO2 Emission                                           [\n127 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n            [Bluetooth, CD player, Radio, Sound system]
# \nExtras\n                                                 [Catalytic Converter]
# \nSafety & Security\n          [ABS, Central door lock, Central door lock wit...
# description                    [\nPrix affiché ttc.8120€ Hors taxes pour expo...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                         [\n01/2019\n, \n127 g CO2/km (comb)\n]
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            8324   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                        1.4i AUTOMAAT 120 Year DAB NAVI CAMERA
# body_type                                                                 Sedans
# price                                                                      13500
# vat                                                                         None
# km                                                                      5,300 km
# registration                                                             03/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                   [\n, \n, \n128 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2019, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,163 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.6 l/100 km (comb)], [7 l/100 km (city)], [...
# CO2 Emission                                           [\n128 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock with remote control, D...
# description                    [\nWagen van de 1ste eigenaar, met Car-Pass. W...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                    [\nBelgium\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            6319   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                               1.6 CDTi 110 CV S&S 5p. Elective
# body_type                                                                 Sedans
# price                                                                       8900
# vat                                                               VAT deductible
# km                                                                    120,000 km
# registration                                                             01/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         60 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                        [\n158934\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                            [\nGrey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[3 l/100 km (comb)], [], [4 l/100 km (country)]]
# CO2 Emission                                            [\n93 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n                      [Air conditioning, Power windows]
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, I...
# description                    [\nCARHAY! - Especialistas en venta de coches ...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            6517   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                         1.6 CDTi 110CV Versione Advance EURO 6
# body_type                                                          Station wagon
# price                                                                      10800
# vat                                                                         None
# km                                                                    101,765 km
# registration                                                             02/2017
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2017, \n]
# Body Color                                                       [\n, Brown, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,403 kg\n]
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.6 l/100 km (comb)], [4 l/100 km (city)], [...
# CO2 Emission                                            [\n95 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n       [Hands-free equipment, On-board computer, Radio]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\n, *** Opel Astra 1.6 CDTi 110CV Versione Ad...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5987   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                                       K Lim. 5türig INNOVATION
# body_type                                                                 Sedans
# price                                                                      13100
# vat                                                               VAT deductible
# km                                                                    104,590 km
# registration                                                             04/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n119 g CO2/km (comb)\n]
# Warranty                                                                     NaN
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                         [\nKarbonschw GraphitSchw Midnigh\n]
# Upholstery                                             [\nFull leather, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.5 l/100 km (comb)], [5.7 l/100 km (city)],...
# CO2 Emission                                           [\n119 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, O...
# \nExtras\n                     [Alloy wheels, Touch screen, Trailer hitch, Vo...
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Central door lo...
# description                    [\n, Sonderausstattung:, Innenraum-Paket, Inno...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7820   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                        1.4 Turbo Auto. ST *NAVI**KLIMAA.**ALU*
# body_type                                                          Station wagon
# price                                                                      23640
# vat                                                               VAT deductible
# km                                                                      6,020 km
# registration                                                             01/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                           [, Used, , Super 95 / Super Plus 98 / Super E1...
# Previous Owners                [\n1\n, \n, 5.4 l/100 km (comb), \n, 7.1 l/100...
# Next Inspection                           [\n06/2021\n, \n125 g CO2/km (comb)\n]
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                          [\n12 months\n, \n4 (Green)\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                [\nAST066785_6439\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                   [\nArgonsilber Metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BHV\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,350 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                           [\n, Super 95 / Super Plus 98 / Super E10 95 /...
# Consumption                    [\n, 5.4 l/100 km (comb), \n, 7.1 l/100 km (ci...
# CO2 Emission                                           [\n125 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Cab or rented Car, Roof rack, T...
# \nSafety & Security\n          [ABS, Adaptive headlights, Central door lock, ...
# description                    [\n,  * Getriebe: 6-Stufen-Automatikgetriebe, ...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                    [[], [], []]
# Availability                                          \nin 1 day from ordering\n
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            8193   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description              ST 1,0 Turbo Ecotec Direct Inj. Österreich Editio
# body_type                                                          Station wagon
# price                                                                      17990
# vat                                                               VAT deductible
# km                                                                          3 km
# registration                                                             03/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                               [, Demonstration, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                      \n03/2022\n
# Inspection new                                                               NaN
# Warranty                                       [\n, \n, \n107 g CO2/km (comb)\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                        [\n205531\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                      [\nOnyx Schwarz (M2)\n]
# Upholstery                                                           [\nCloth\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                    NaN
# Weight                                                            [\n1,288 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[4.6 l/100 km (comb)], [5.4 l/100 km (city)],...
# CO2 Emission                                           [\n107 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                               [Alloy wheels, Roof rack, Touch screen]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nAutom.Parkassistent, LED Rückleuchten, Flex...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            2132   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description              Sportback 30 TFSI S tronic Navi+/virtual/EPH+/SMA
# body_type                                                                 Sedans
# price                                                                      24490
# vat                                                               VAT deductible
# km                                                                      3,000 km
# registration                                                             06/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n06/2021\n, \n108 g CO2/km (comb)\n]
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                          [\n36 months\n, \n4 (Green)\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                        [\n036987\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                          [\nMythosschwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BNO\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[4.8 l/100 km (comb)], [5.8 l/100 km (city)],...
# CO2 Emission                                           [\n108 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Touch scre...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Anschlussgarantie 1 Jahr max. 60.000 km, ...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            4361   \
# url                            https://www.autoscout24.com//offers/audi-a3-1-...
# make_model                                                               Audi A3
# short_description                                              1.2 TFSI Ambiente
# body_type                                                                 Sedans
# price                                                                      16000
# vat                                                                         None
# km                                                                     60,000 km
# registration                                                             03/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                  \n
# Non-smoking Vehicle                            [\n, \n, \n114 g CO2/km (comb)\n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2017, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,197 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,255 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[4.9 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n                    [CD player, MP3, On-board computer]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock with remote control, D...
# description                    [\nÀ vendre Audi A3 , 110ch essence 60000km, V...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            14702  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                                           LIMITED TCe 75 KLIMA
# body_type                                                                Compact
# price                                                                      11400
# vat                                                               VAT deductible
# km                                                                        150 km
# registration                                                             04/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         56 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n04/2022\n, \n113 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                   [\nGW Nr. 6675\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                         [\n, Red, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                      [\nIntense-Rot (NPK)\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n3333/BAJ\n]
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n898 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5 l/100 km (comb)], [6.3 l/100 km (city)], [...
# CO2 Emission                                           [\n113 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nTAGESZULASSUNG - DEUTSCHES FAHRZEUG, inkl. ...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            9904   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                      E 1.4 120 Jahre/AUTOMATIK/SHZ/LHZ/PDC/TOP
# body_type                                                                Compact
# price                                                                      16790
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                             03/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                              [, Pre-registered, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n03/2022\n, \n143 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# ...
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,250 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[3.7 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2 Emission                                            [\n97 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Electrical side mirrors, Le...
# \nEntertainment & Media\n                                                [Radio]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Central door lock wit...
# description                    [\nEl precio reflejado en el anuncio es precio...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                      [\nSpain\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            14027  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description              TCe 120 EDC INTENS / CLIMA / NAVI / LED / 17''...
# body_type                                                                Compact
# price                                                                      17900
# vat                                                               VAT deductible
# km                                                                     15,293 km
# registration                                                             03/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         87 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                      \n03/2021\n
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                   [\n, \n, \n120 g CO2/km (comb)\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                        [\nSX136R\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                  [\nGrijs\n]
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,197 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,065 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.4 l/100 km (comb)], [6.8 l/100 km (city)],...
# CO2 Emission                                           [\n120 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                    [On-board computer]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\nSupercomplete Clio automaat, met oa climate...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                [\nNetherlands\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7716   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                         Sports Tourer 120 Jahre +Navi+PDC+LED+
# body_type                                                          Station wagon
# price                                                                      26341
# vat                                                               VAT deductible
# km                                                                        301 km
# registration                                                             02/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                           [, Demonstration, , Super E10 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n02/2022\n, \n0 kWh/100 km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                [\n24 months\n, \n134 g CO2/km (comb)\n]
# Full Service                                          [\n, \n, \nEuro 6d-TEMP\n]
# Non-smoking Vehicle                                      [\n, \n, \n4 (Green)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                     [\n032328-KF\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nArgon Silber\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,398 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                      [\n, Super E10 95, \n]
# Consumption                    [[5.8 l/100 km (comb)], [7.4 l/100 km (city)],...
# CO2 Emission                                           [\n134 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Digital radio, Hands-free equipmen...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Roof rack,...
# \nSafety & Security\n          [ABS, Adaptive headlights, Blind spot monitor,...
# description                    [\n, Highlights: ,  Herstellereigene Garantie ...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                [\n0 kWh/100 km (comb)\n]
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            3314
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                           SPB 1.6 TDI 116 CV S tronic Business
# body_type                                                                 Sedans
# price                                                                      24500
# vat                                                                         None
# km                                                                     23,484 km
# registration                                                             03/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                      [\nNERO METALLIZZATO\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                            [\n, Semi-automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,360 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[3.9 l/100 km (comb)], [4.1 l/100 km (city)],...
# CO2 Emission                                           [\n103 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                                         [Alloy wheels, Voice Control]
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Alarm system, C...
# description                    [\n, AUDI PRIMA SCELTA PLUS - VETTURA IN OTTIM...
# Emission Label                                                               NaN
# Gears                                                                    [\n7\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %% [markdown]
# <br>

# %% [markdown]
# - Here that we have got some random rows. I have to admit that I did not fall in love at first sight since it is such a messy data. :)
# - As you can see, there are so mays things that we need to do !
# - Just to make sure that we do not miss anything, I am going to make a list about things that I need to work on.

# %% [markdown]
# <br>

# %% [markdown]
# ### Things Needs to Be Done
#
# 1. Think about removing url column.
# 2. **Get rid of the column "make_model"**
# 3. **Short description
# 4. Body_type : There are 60 nulls values that we have to deal with.
# 5. Be aware of outliers such as min. in price column.
# 6. Vat column : Change it to deductible or not deductible
# 7. For the km column remove the "km" from the rows and change the data type to int or float.
# 8. **Drop the registration column because there is another registratio colum which only contains years.**
# 9. **From prev_owner column remove the part of "previous owner" and change data type to integer. There are 6828 null values.Remove the "Previous owners" column.**
# 10. **Drop the column "kW"**
# 11. Change the "hp" column name to kW.Change the data type.
# 12. Clean the "Type" column.
# 13. **Drop the columns about inspectation.**
# 14. Come back to the Warranty column
# 15. **Drop the Full service column.**
# 16. **Drop the Non_smoking column.**
# 17. **Drop the null column.**
# 18. Clean both make and model columns.
# 19. Come back to the offer number column again.
# 20. Change the First registration column name as Registration year
# 21. **Drop the Body color original**
# 22. Organize Upholstery column
# 23. **Drop the Body column.**
# 24. Check the number of doors
# 25. For the number od seats, clean '\n'
# 26. **Drop the model code number  column**
# 27. Clean the outliers for gearing type column
# 28. For the Cyclinder column clean the outliers.
# 29. **You might drop Weight column(!)**
# 30. Make the small groups for Fuel column.
# 31. We might need the 'Consumption' to be in 3 different column.
# 32. For the CO2 Emission, get rid of the unnecessary string parts and change the column name.
# 33. For the Emission Class column be aware of empty brackets which are null valus and get rid of unnecessary inf.
# 34. Come back to the \nComfort & Convenience\n column.
# 35. Come back to '\nEntertainment & Media\n' column.
# 36. Extras column*
# 37. Safety & Security column*
# 38. **Drop the description column.**
# 39. **Drop the emission column.**
# 40. Gears column*
# 41. **Drop rest of the columns.**

# %% [markdown]
# <br>

# %% [markdown]
# - First I looked into our columns one by one and figured the things that needs to be done and made a list.
# - To have a better outlook I did not add all the analysis I have done so far since they are a lot.
# - Some of them might be removed or new items can be added by process.

# %% [markdown]
# ---

# %% [markdown]
# - I am going to start with dropping the columns that I am not going to need.
# - I will be using the copy of my data frame.

# %%
df1 = df.copy()

# %%
df1.sample(2).T
# Out:
#                                                                             3969  \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description              Sportback 1.0 TFSI Klima Navi Xenon Alu Sitzhe...
# body_type                                                                 Sedans
# price                                                                      19990
# vat                                                               VAT deductible
# km                                                                     16,139 km
# registration                                                             02/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                              [, Used, , Regular/Benzine 91]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n104 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                         [\n14880\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                      [\nNanograu Metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BHX\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                [\n, Regular/Benzine 91, \n]
# Consumption                    [[4.5 l/100 km (comb)], [5.4 l/100 km (city)],...
# CO2 Emission                                           [\n104 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Electrical side mirrors, Le...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                     [Alloy wheels, Cab or rented Car, Catalytic Co...
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Highlights:, Anschlussgarantie 1 Jahr, ma...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                             6597
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                                  1.6 CDTI Automatik Innovation
# body_type                                                                 Sedans
# price                                                                      17680
# vat                                                               VAT deductible
# km                                                                     25,281 km
# registration                                                             04/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n06/2021\n, \n115 g CO2/km (comb)\n]
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                                 [\n, \n, \n4 (Green)\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                          [\n8149\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                        [\n, Blue, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                  [\nDiamant Blau Metallic\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BFQ\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,364 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.4 l/100 km (comb)], [5.5 l/100 km (city)],...
# CO2 Emission                                           [\n115 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Digital radio, Hands-free equipmen...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n,  * ABS mit CBC und Bremsassistent,  * Abl...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df1.drop('url', axis = 1, inplace = True)
df1.drop('make_model', axis = 1, inplace = True)
df1.drop('short_description', axis = 1, inplace = True)
df1.drop('kW', axis = 1, inplace = True)
df1.drop('registration', axis = 1, inplace = True)
df1.drop('Previous Owners', axis = 1, inplace = True)
df1.drop('Next Inspection', axis = 1, inplace = True)
df1.drop('Inspection new', axis = 1, inplace = True)
df1.drop('Full Service', axis = 1, inplace = True)
df1.drop('null', axis = 1, inplace = True)
df1.drop('Body Color Original', axis = 1, inplace = True)
df1.drop('Body', axis = 1, inplace = True)
df1.drop('Model Code', axis = 1, inplace = True)
df1.drop('Weight', axis = 1, inplace = True)
df1.drop('description', axis = 1, inplace = True)
df1.drop('Emission Label', axis = 1, inplace = True)
df1.drop('Country version', axis = 1, inplace = True)
df1.drop('Electricity consumption', axis = 1, inplace = True)
df1.drop('Last Service Date', axis = 1, inplace = True)
df1.drop('Other Fuel Types', axis = 1, inplace = True)
df1.drop('Availability', axis = 1, inplace = True)
df1.drop('Last Timing Belt Service Date', axis = 1, inplace = True)
df1.drop('Available from', axis = 1, inplace = True)
df1.drop('Non-smoking Vehicle', axis = 1, inplace = True)

# %%
df1.drop('Offer Number', axis = 1, inplace = True)

# %%
df1.sample(1).T
# Out:
#                                                                        15372
# body_type                                                                Van
# price                                                                  27890
# vat                                                                     None
# km                                                                 21,978 km
# prev_owner                                                 2 previous owners
# hp                                                                     96 kW
# Type                                 [, Used, , Diesel (Particulate Filter)]
# Warranty                                                                 NaN
# Make                                                                 Renault
# Model                                                       [\n, Espace, \n]
# First Registration                                            [\n, 2017, \n]
# Body Color                                                  [\n, Silver, \n]
# Paint Type                                                    [\nMetallic\n]
# Upholstery                                                               NaN
# Nr. of Doors                                                         [\n5\n]
# Nr. of Seats                                                         [\n5\n]
# Gearing Type                                                [\n, Manual, \n]
# Displacement                                                  [\n1,598 cc\n]
# Cylinders                                                                NaN
# Drive chain                                                              NaN
# Fuel                                   [\n, Diesel (Particulate Filter), \n]
# Consumption                                                              NaN
# CO2 Emission                                                    [[], [], []]
# Emission Class                                                           NaN
# \nComfort & Convenience\n  [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                [Bluetooth, On-board computer, USB]
# \nExtras\n                                                    [Alloy wheels]
# \nSafety & Security\n      [ABS, Adaptive headlights, Central door lock, ...
# Gears                                                                [\n6\n]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   body_type                15859 non-null  object
#  1   price                    15919 non-null  int64
#  2   vat                      11406 non-null  object
#  3   km                       15919 non-null  object
#  4   prev_owner               9091 non-null   object
#  5   hp                       15919 non-null  object
#  6   Type                     15917 non-null  object
#  7   Warranty                 10499 non-null  object
#  8   Make                     15919 non-null  object
#  9   Model                    15919 non-null  object
#  10  Offer Number             12744 non-null  object
#  11  First Registration       14322 non-null  object
#  12  Body Color               15322 non-null  object
#  13  Paint Type               10147 non-null  object
#  14  Upholstery               12199 non-null  object
#  15  Nr. of Doors             15707 non-null  object
#  16  Nr. of Seats             14942 non-null  object
#  17  Gearing Type             15919 non-null  object
#  18  Displacement             15423 non-null  object
#  19  Cylinders                10239 non-null  object
#  20  Drive chain              9061 non-null   object
#  21  Fuel                     15919 non-null  object
#  22  Consumption              14013 non-null  object
#  23  CO2 Emission             14111 non-null  object
#  24  Emission Class           12898 non-null  object
#  25
# Comfort & Convenience
#   14999 non-null  object
#  26
# Entertainment & Media
#   14545 non-null  object
#  27
# Extras
#                  12957 non-null  object
#  28
# Safety & Security
#       14937 non-null  object
#  29  Gears                    11207 non-null  object
# dtypes: int64(1), object(29)
# memory usage: 3.6+ MB

# %% [markdown]
# - After dropping unnecessary columns, let's start orginizing rest of them.

# %% [markdown]
# #### Km - Cleaning

# %%
df1.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %% [markdown]
# - We need to get rid of the "km" part and the "-" rows then change the data type to float.

# %%
df1.km = df1.km.astype('str').replace('- km', np.nan)
df1.km  = df1.km.str.strip(" km")
df1.km = df1.km.str.replace(",", "")
df1.km = df1.km.astype(float)

# %%
df1.km
# Out:
# 0        56013.0
# 1        80000.0
# 2        83450.0
# 3        73000.0
# 4        16200.0
#           ...
# 15914        NaN
# 15915     9900.0
# 15916       15.0
# 15917       10.0
# 15918        NaN
# Name: km, Length: 15919, dtype: float64

# %% [markdown]
# #### kW - Cleaning

# %%
df1.rename(columns={'hp':'kw'}, inplace = True )
df1.kw = df1.kw.str.strip(' kW')
df1.kw = df1.kw.replace(0,np.nan)
df1.kw = df1.kw.replace('-', np.nan)
df1.kw = df1.kw.astype(float)

# %%
df1.kw
# Out:
# 0         66.0
# 1        141.0
# 2         85.0
# 3         66.0
# 4         66.0
#          ...
# 15914    147.0
# 15915    165.0
# 15916    146.0
# 15917    147.0
# 15918    165.0
# Name: kw, Length: 15919, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# #### Prev_owner - Cleaning

# %%
df1.prev_owner
# Out:
# 0        2 previous owners
# 1                     None
# 2         1 previous owner
# 3         1 previous owner
# 4         1 previous owner
#                ...
# 15914                 None
# 15915     1 previous owner
# 15916     1 previous owner
# 15917                 None
# 15918     1 previous owner
# Name: prev_owner, Length: 15919, dtype: object

# %%
df1.prev_owner = df1.prev_owner.str.strip(' previous owner')
df1.prev_owner = df1.prev_owner.astype(float)
df1.prev_owner
# Out:
# 0        2.0
# 1        NaN
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 15914    NaN
# 15915    1.0
# 15916    1.0
# 15917    NaN
# 15918    1.0
# Name: prev_owner, Length: 15919, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# #### Make - Cleaning

# %%
df1.Make
# Out:
# 0           \nAudi\n
# 1           \nAudi\n
# 2           \nAudi\n
# 3           \nAudi\n
# 4           \nAudi\n
#             ...
# 15914    \nRenault\n
# 15915    \nRenault\n
# 15916    \nRenault\n
# 15917    \nRenault\n
# 15918    \nRenault\n
# Name: Make, Length: 15919, dtype: object

# %%
df1.Make = df1.Make.str.strip('\n')

# %%
df1.Make
# Out:
# 0           Audi
# 1           Audi
# 2           Audi
# 3           Audi
# 4           Audi
#           ...
# 15914    Renault
# 15915    Renault
# 15916    Renault
# 15917    Renault
# 15918    Renault
# Name: Make, Length: 15919, dtype: object

# %% [markdown]
# #### Model - Cleaning

# %%
df1.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
df1.Model=df1.Model.str[1].str.strip('\n')
df1.Model
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### Type - Cleaning

# %%
df1.Type
# Out:
# 0                  [, Used, , Diesel (Particulate Filter)]
# 1                                     [, Used, , Gasoline]
# 2                  [, Used, , Diesel (Particulate Filter)]
# 3                  [, Used, , Diesel (Particulate Filter)]
# 4                  [, Used, , Diesel (Particulate Filter)]
#                                ...
# 15914               [, New, , Diesel (Particulate Filter)]
# 15915    [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916                         [, Pre-registered, , Diesel]
# 15917                         [, Pre-registered, , Diesel]
# 15918                        [, Demonstration, , Super 95]
# Name: Type, Length: 15919, dtype: object

# %%
df1.Type = df1.Type.str[1]

# %%
df1.Type
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: Type, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# ### Renaming the Columns

# %%
df1.rename(columns={'Type':'Condition'}, inplace = True)
df1.rename(columns={'body_type':'Body_Type'}, inplace = True)
df1.rename(columns={'price':'Price'}, inplace = True)
df1.rename(columns={'vat':'Vat'}, inplace = True)
df1.rename(columns={'prev_owner':'Previous_Owner'}, inplace = True)
df1.rename(columns={'First Registration':'Registration_Year'}, inplace = True)
df1.rename(columns={'Body Color':'Body_Color'}, inplace = True)
df1.rename(columns={'Paint Type':'Paint_Type'}, inplace = True)
df1.rename(columns={'Nr. of Doors':'Nr_of_Doors'}, inplace = True)
df1.rename(columns={'Nr. of Seats':'Nr_of_Seats'}, inplace = True)
df1.rename(columns={'Gearing Type':'Gearing_Type'}, inplace = True)
df1.rename(columns={'CO2 Emission':'CO2_Emission'}, inplace = True)
df1.rename(columns={'Emission Class':'Emission_Class'}, inplace = True)
df1.rename(columns={'\nComfort & Convenience\n':'Comfort_Convenience'}, inplace = True)
df1.rename(columns={'\nEntertainment & Media\n':'Entertainment_Media'}, inplace = True)
df1.rename(columns={'\nExtras\n':'Extras'}, inplace = True)
df1.rename(columns={'\nSafety & Security\n':'Safety & Security'}, inplace = True)
df1.rename(columns={'kw':'kW'}, inplace = True)
df1.rename(columns={'Safety & Security':'Safety_Security'}, inplace = True)
df1.rename(columns={'Drive chain':'Drive_Chain'}, inplace = True)
df1.rename(columns={'km':'Km'}, inplace = True)

# %%
df1.sample(3).T
# Out:
#                                                                   4963  \
# Body_Type                                                       Sedans
# Price                                                            21790
# Vat                                                               None
# Km                                                             14450.0
# Previous_Owner                                                     1.0
# kW                                                                85.0
# Condition                                                         Used
# Warranty                                                           NaN
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                       [\n, 2018, \n]
# Body_Color                                              [\n, Grey, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                                 [\nCloth\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                [\nfront\n]
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2_Emission                                 [\n108 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n6\n]
#
#                                                                   8687  \
# Body_Type                                                       Sedans
# Price                                                             7450
# Vat                                                     VAT deductible
# Km                                                             87000.0
# Previous_Owner                                                     1.0
# kW                                                                70.0
# Condition                                                         Used
# Warranty                                                           NaN
# Make                                                              Opel
# Model                                                            Corsa
# Registration_Year                                       [\n, 2016, \n]
# Body_Color                                              [\n, Blue, \n]
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,248 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption                            [[3.8 l/100 km (comb)], [], []]
# CO2_Emission                                 [\n101 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Cruise control, Electrical ...
# Entertainment_Media  [Bluetooth, CD player, On-board computer, Radi...
# Extras                                                  [Winter tyres]
# Safety_Security      [ABS, Central door lock, Central door lock wit...
# Gears                                                          [\n5\n]
#
#                                                                   5225
# Body_Type                                                       Sedans
# Price                                                            25539
# Vat                                                     VAT deductible
# Km                                                                 1.0
# Previous_Owner                                                     NaN
# kW                                                               110.0
# Condition                                                          New
# Warranty                             [\n, \n, \n125 g CO2/km (comb)\n]
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                                  NaN
# Body_Color                                                         NaN
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,498 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                           [\n, Super 95 (Particulate Filter), \n]
# Consumption          [[5.5 l/100 km (comb)], [6.9 l/100 km (city)],...
# CO2_Emission                                 [\n125 g CO2/km (comb)\n]
# Emission_Class                                      [\nEuro 6d-TEMP\n]
# Comfort_Convenience  [Air conditioning, Electrical side mirrors, Mu...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, M...
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN

# %% [markdown]
# <br>

# %% [markdown]
# #### Warranty - Dropping

# %%
df1.drop('Warranty', axis = 1, inplace = True)

# %% [markdown]
# #### Registration_Year - Cleaning

# %%
df1.Registration_Year
# Out:
# 0        [\n, 2016, \n]
# 1        [\n, 2017, \n]
# 2        [\n, 2016, \n]
# 3        [\n, 2016, \n]
# 4        [\n, 2016, \n]
#               ...
# 15914               NaN
# 15915    [\n, 2019, \n]
# 15916    [\n, 2019, \n]
# 15917    [\n, 2019, \n]
# 15918    [\n, 2019, \n]
# Name: Registration_Year, Length: 15919, dtype: object

# %%
df1.Registration_Year = df1.Registration_Year.str[1]

# %%
df1.Registration_Year
# Out:
# 0        2016
# 1        2017
# 2        2016
# 3        2016
# 4        2016
#          ...
# 15914     NaN
# 15915    2019
# 15916    2019
# 15917    2019
# 15918    2019
# Name: Registration_Year, Length: 15919, dtype: object

# %%
df1.sample(3).T
# Out:
#                                                                  2669   \
# Body_Type                                                      Compact
# Price                                                            18450
# Vat                                                               None
# Km                                                             66045.0
# Previous_Owner                                                     NaN
# kW                                                                81.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                                 2016
# Body_Color                                              [\n, Grey, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                                                  [\n, Diesel, \n]
# Consumption          [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2_Emission                                 [\n105 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media         [CD player, MP3, On-board computer, Radio]
# Extras                                                  [Alloy wheels]
# Safety_Security      [ABS, Adaptive headlights, Central door lock, ...
# Gears                                                          [\n7\n]
#
#                                                                  6232   \
# Body_Type                                                Station wagon
# Price                                                             9750
# Vat                                                     VAT deductible
# Km                                                             69000.0
# Previous_Owner                                                     1.0
# kW                                                                74.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                            Astra
# Registration_Year                                                 2016
# Body_Color                                            [\n, Silver, \n]
# Paint_Type                                                         NaN
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n4\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,399 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                                                [\n, Gasoline, \n]
# Consumption          [[5.5 l/100 km (comb)], [7.5 l/100 km (city)],...
# CO2_Emission                                 [\n127 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Cruise control, Electrical ...
# Entertainment_Media   [Bluetooth, CD player, On-board computer, Radio]
# Extras                                                             NaN
# Safety_Security      [ABS, Central door lock, Electronic stability ...
# Gears                                                              NaN
#
#                                                                  13250
# Body_Type                                                       Sedans
# Price                                                            14699
# Vat                                                     VAT deductible
# Km                                                             16000.0
# Previous_Owner                                                     1.0
# kW                                                                66.0
# Condition                                                         Used
# Make                                                           Renault
# Model                                                             Clio
# Registration_Year                                                 2018
# Body_Color                                            [\n, Silver, \n]
# Paint_Type                                              [\nMetallic\n]
# Upholstery                                   [\nPart leather, Black\n]
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n5\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,461 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                             [\n, Diesel (Particulate Filter), \n]
# Consumption          [[3.5 l/100 km (comb)], [3.9 l/100 km (city)],...
# CO2_Emission                                  [\n92 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, Digital radio, Hands-free equipmen...
# Extras               [Alloy wheels, Catalytic Converter, Touch scre...
# Safety_Security      [ABS, Adaptive headlights, Central door lock, ...
# Gears                                                          [\n6\n]

# %% [markdown]
# <br>

# %% [markdown]
# #### Body_Color - Cleaning

# %%
df1.Body_Color
# Out:
# 0        [\n, Black, \n]
# 1          [\n, Red, \n]
# 2        [\n, Black, \n]
# 3        [\n, Brown, \n]
# 4        [\n, Black, \n]
#               ...
# 15914     [\n, Grey, \n]
# 15915     [\n, Grey, \n]
# 15916    [\n, White, \n]
# 15917     [\n, Grey, \n]
# 15918     [\n, Grey, \n]
# Name: Body Color, Length: 15919, dtype: object

# %%
df1.Body_Color = df1.Body_Color.str[1]

# %% [markdown]
# <br>

# %% [markdown]
# #### Upholstery - Cleaning

# %%
df1.Upholstery
# Out:
# 0               [\nCloth, Black\n]
# 1                [\nCloth, Grey\n]
# 2               [\nCloth, Black\n]
# 3                              NaN
# 4               [\nCloth, Black\n]
#                    ...
# 15914                          NaN
# 15915                  [\nCloth\n]
# 15916    [\nFull leather, Black\n]
# 15917           [\nPart leather\n]
# 15918    [\nFull leather, Brown\n]
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1["Upholstery"] = df1["Upholstery"].apply(lambda item: item[0] if type(item) == list else item)
df1.Upholstery = df1.Upholstery.str.strip("\n")

# %%
df1.Upholstery
# Out:
# 0               Cloth, Black
# 1                Cloth, Grey
# 2               Cloth, Black
# 3                        NaN
# 4               Cloth, Black
#                 ...
# 15914                    NaN
# 15915                  Cloth
# 15916    Full leather, Black
# 15917           Part leather
# 15918    Full leather, Brown
# Name: Upholstery, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### Paint_Type - Cleaning

# %%
df1.Paint_Type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-08c32c8b9b08> in <module>
# ----> 1 df1.Paint_Type
#
# NameError: name 'df1' is not defined

# %%
df1.Paint_Type = df1["Paint_Type"].apply(lambda item: item[0] if type(item) == list else item)
df1.Paint_Type = df1.Paint_Type.str.strip('\n')
df1.Paint_Type
# Out:
# 0        Metallic
# 1             NaN
# 2        Metallic
# 3        Metallic
# 4        Metallic
#            ...
# 15914    Metallic
# 15915    Metallic
# 15916         NaN
# 15917         NaN
# 15918    Metallic
# Name: Paint_Type, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### Nr. of Doors and Seats - Cleaning

# %%
df1.Nr_of_Doors
# Out:
# 0        [\n5\n]
# 1        [\n3\n]
# 2        [\n4\n]
# 3        [\n3\n]
# 4        [\n5\n]
#           ...
# 15914    [\n5\n]
# 15915    [\n5\n]
# 15916    [\n5\n]
# 15917    [\n5\n]
# 15918    [\n5\n]
# Name: Nr_of_Doors, Length: 15919, dtype: object

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.apply(lambda item: item[0] if type(item) == list else item)
df1.Nr_of_Doors = df1.Nr_of_Doors.str.strip('\n')
df1.Nr_of_Doors
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: Nr_of_Doors, Length: 15919, dtype: object

# %% [markdown]
# ---

# %%
df1.Nr_of_Seats
# Out:
# 0        [\n5\n]
# 1        [\n4\n]
# 2        [\n4\n]
# 3        [\n4\n]
# 4        [\n5\n]
#           ...
# 15914    [\n5\n]
# 15915    [\n5\n]
# 15916    [\n7\n]
# 15917    [\n7\n]
# 15918    [\n5\n]
# Name: Nr_of_Seats, Length: 15919, dtype: object

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.apply(lambda item: item[0] if type(item) == list else item)
df1.Nr_of_Seats = df1.Nr_of_Seats.str.strip('\n')

# %%
df1.Nr_of_Seats
# Out:
# 0        5
# 1        4
# 2        4
# 3        4
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    7
# 15917    7
# 15918    5
# Name: Nr_of_Seats, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### Gearing Type - Cleaning

# %%
df1.Gearing_Type
# Out:
# 0        [\n, Automatic, \n]
# 1        [\n, Automatic, \n]
# 2        [\n, Automatic, \n]
# 3        [\n, Automatic, \n]
# 4        [\n, Automatic, \n]
#                 ...
# 15914    [\n, Automatic, \n]
# 15915    [\n, Automatic, \n]
# 15916    [\n, Automatic, \n]
# 15917    [\n, Automatic, \n]
# 15918    [\n, Automatic, \n]
# Name: Gearing_Type, Length: 15919, dtype: object

# %%
df1.Gearing_Type = df1.Gearing_Type.apply(lambda item: item[1] if type(item) == list else item)
df1.Gearing_Type = df1.Gearing_Type.str.strip('\n')

# %%
df1.Gearing_Type
# Out:
# 0        Automatic
# 1        Automatic
# 2        Automatic
# 3        Automatic
# 4        Automatic
#            ...
# 15914    Automatic
# 15915    Automatic
# 15916    Automatic
# 15917    Automatic
# 15918    Automatic
# Name: Gearing_Type, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### Displacement - Cleaning

# %%
df1.Displacement
# Out:
# 0        [\n1,422 cc\n]
# 1        [\n1,798 cc\n]
# 2        [\n1,598 cc\n]
# 3        [\n1,422 cc\n]
# 4        [\n1,422 cc\n]
#               ...
# 15914    [\n1,997 cc\n]
# 15915    [\n1,798 cc\n]
# 15916    [\n1,997 cc\n]
# 15917    [\n1,997 cc\n]
# 15918    [\n1,798 cc\n]
# Name: Displacement, Length: 15919, dtype: object

# %%
df1.Displacement = df1.Displacement.apply(lambda item: item[0] if type(item) == list else item)
df1.Displacement = df1.Displacement.str.strip('\n').str.strip(' cc\n')
df1.Displacement  = df1.Displacement.str.replace(',','')
df1.Displacement=df1.Displacement.astype(float)

# %%
df1.Displacement
# Out:
# 0        1422.0
# 1        1798.0
# 2        1598.0
# 3        1422.0
# 4        1422.0
#           ...
# 15914    1997.0
# 15915    1798.0
# 15916    1997.0
# 15917    1997.0
# 15918    1798.0
# Name: Displacement, Length: 15919, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# #### Cylinders - Cleaning

# %%
df1.Cylinders
# Out:
# 0        [\n3\n]
# 1        [\n4\n]
# 2            NaN
# 3        [\n3\n]
# 4        [\n3\n]
#           ...
# 15914    [\n4\n]
# 15915    [\n4\n]
# 15916    [\n4\n]
# 15917    [\n4\n]
# 15918    [\n4\n]
# Name: Cylinders, Length: 15919, dtype: object

# %%
df1.Cylinders = df1.Cylinders.str[0].str.strip('\n').astype(float)

# %%
df1.Cylinders
# Out:
# 0        3.0
# 1        4.0
# 2        NaN
# 3        3.0
# 4        3.0
#         ...
# 15914    4.0
# 15915    4.0
# 15916    4.0
# 15917    4.0
# 15918    4.0
# Name: Cylinders, Length: 15919, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# #### Drice_Chain - Cleaning

# %%
df1.Drive_Chain
# Out:
# 0        [\nfront\n]
# 1        [\nfront\n]
# 2        [\nfront\n]
# 3                NaN
# 4        [\nfront\n]
#             ...
# 15914    [\nfront\n]
# 15915    [\nfront\n]
# 15916    [\nfront\n]
# 15917    [\nfront\n]
# 15918      [\n4WD\n]
# Name: Drive_Chain, Length: 15919, dtype: object

# %%
df1.Drive_Chain = df1.Drive_Chain.str[0].str.strip('\n')
df1.Drive_Chain
# Out:
# 0        front
# 1        front
# 2        front
# 3          NaN
# 4        front
#          ...
# 15914    front
# 15915    front
# 15916    front
# 15917    front
# 15918      4WD
# Name: Drive_Chain, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### Fuel - Cleaning

# %%
df1.Fuel
# Out:
# 0                    [\n, Diesel (Particulate Filter), \n]
# 1                                       [\n, Gasoline, \n]
# 2                    [\n, Diesel (Particulate Filter), \n]
# 3                    [\n, Diesel (Particulate Filter), \n]
# 4                    [\n, Diesel (Particulate Filter), \n]
#                                ...
# 15914                [\n, Diesel (Particulate Filter), \n]
# 15915    [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                     [\n, Diesel, \n]
# 15917                                     [\n, Diesel, \n]
# 15918                                   [\n, Super 95, \n]
# Name: Fuel, Length: 15919, dtype: object

# %%
df1.Fuel = df1.Fuel.str[1].str.strip('\n')

# %%
df1.Fuel.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                          Diesel (Particulate Filter)
# 1                                             Gasoline
# 2                          Diesel (Particulate Filter)
# 3                          Diesel (Particulate Filter)
# 4                          Diesel (Particulate Filter)
#                              ...
# 15914                      Diesel (Particulate Filter)
# 15915    Super 95 / Super Plus 98 (Particulate Filter)
# 15916                                           Diesel
# 15917                                           Diesel
# 15918                                         Super 95
# Name: Fuel, Length: 15919, dtype: object>

# %%
def Fuel_type(x):
    if "Benzine" in x :
        return "Gasoline"
    elif "Gasoline" in x :
        return "Gasoline"
    elif "Super" in x :
        return "Gasoline"
    elif "Diesel" in x :
        return "Diesel"
    elif "LPG" in x :
        return "LPG"
    else :
        return "Others"

# %%
df1.Fuel = df1.Fuel.apply(Fuel_type)
df1.Fuel.value_counts()
# Out:
# Gasoline    8549
# Diesel      7299
# Others        45
# LPG           26
# Name: Fuel, dtype: int64

# %% [markdown]
# <br>

# %% [markdown]
# #### Consumption - Cleaning

# %%
df1.Consumption
# Out:
# 0        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1        [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2        [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4        [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
#                                ...
# 15914    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915    [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918    [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
# Name: Consumption, Length: 15919, dtype: object

# %% [markdown]
# - No need for unnecessary inf so I am going to work with only "Combined"

# %%
df1['Combined_Cons'] = df1.Consumption.str[0].str[0].str.split().str[0]

# %%
df1.Combined_Cons=df1.Combined_Cons.astype(float)

# %%
df1.Combined_Cons
# Out:
# 0        3.8
# 1        5.6
# 2        3.8
# 3        3.8
# 4        4.1
#         ...
# 15914    5.3
# 15915    NaN
# 15916    5.3
# 15917    5.3
# 15918    6.8
# Name: Combined_Cons, Length: 15919, dtype: float64

# %%
df1.sample(3).T
# Out:
#                                                                   1030  \
# Body_Type                                                       Sedans
# Price                                                            20570
# Vat                                                     VAT deductible
# Km                                                              3300.0
# Previous_Owner                                                     1.0
# kW                                                                66.0
# Condition                                               Employee's car
# Make                                                              Audi
# Model                                                               A1
# Registration_Year                                                 2018
# Body_Color                                                         Red
# Paint_Type                                                    Metallic
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                          4
# Nr_of_Seats                                                          5
# Gearing_Type                                                 Automatic
# Displacement                                                    1422.0
# Cylinders                                                          3.0
# Drive_Chain                                                      front
# Fuel                                                            Diesel
# Consumption          [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2_Emission                                 [\n104 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, Digital radio, Hands-fr...
# Extras                      [Alloy wheels, Sport seats, Voice Control]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
# Combined_Cons                                                      4.0
#
#                                                                   2820  \
# Body_Type                                                       Sedans
# Price                                                            16999
# Vat                                                               None
# Km                                                             65000.0
# Previous_Owner                                                     NaN
# kW                                                                81.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                                 2016
# Body_Color                                                       Black
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                 Automatic
# Displacement                                                    1598.0
# Cylinders                                                          4.0
# Drive_Chain                                                        NaN
# Fuel                                                            Diesel
# Consumption          [[4 l/100 km (comb)], [4.5 l/100 km (city)], [...
# CO2_Emission                                 [\n105 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Cruise control, El...
# Entertainment_Media           [Bluetooth, Hands-free equipment, Radio]
# Extras                                   [Alloy wheels, Voice Control]
# Safety_Security      [ABS, Central door lock, Central door lock wit...
# Gears                                                          [\n7\n]
# Combined_Cons                                                      4.0
#
#                                                                   3872
# Body_Type                                                       Sedans
# Price                                                            20500
# Vat                                                               None
# Km                                                             52000.0
# Previous_Owner                                                     NaN
# kW                                                                85.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                                 2018
# Body_Color                                                       White
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                 Automatic
# Displacement                                                    1598.0
# Cylinders                                                          4.0
# Drive_Chain                                                      front
# Fuel                                                            Diesel
# Consumption          [[3.9 l/100 km (comb)], [4.2 l/100 km (city)],...
# CO2_Emission                                 [\n103 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Cruise control, El...
# Entertainment_Media   [Bluetooth, CD player, MP3, Radio, Sound system]
# Extras                                     [Alloy wheels, Sport seats]
# Safety_Security      [ABS, Adaptive Cruise Control, Central door lo...
# Gears                                                          [\n7\n]
# Combined_Cons                                                      3.9

# %% [markdown]
# - Since we do not need the Consumption column, we can drop it.

# %%
df1.drop('Consumption', axis = 1, inplace = True)

# %% [markdown]
# <br>

# %% [markdown]
# #### CO2_Emission - Emission_Class - Dropping

# %%
df1.drop('CO2_Emission', axis = 1, inplace = True)
df1.drop('Emission_Class', axis = 1, inplace = True)

# %%
df1.sample(3).T
# Out:
#                                                                  14974  \
# Body_Type                                                Station wagon
# Price                                                            27500
# Vat                                                               None
# Km                                                             31200.0
# Previous_Owner                                                     NaN
# kW                                                               147.0
# Condition                                                         Used
# Make                                                           Renault
# Model                                                           Espace
# Registration_Year                                                 2016
# Body_Color                                                       White
# Paint_Type                                                         NaN
# Upholstery                                         Full leather, Other
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          7
# Gearing_Type                                                 Automatic
# Displacement                                                    1618.0
# Cylinders                                                          4.0
# Drive_Chain                                                      front
# Fuel                                                          Gasoline
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, Hands-free equipment, On-board com...
# Extras                                    [Alloy wheels, Touch screen]
# Safety_Security      [ABS, Blind spot monitor, Central door lock, D...
# Gears                                                          [\n7\n]
# Combined_Cons                                                      5.3
#
#                                                                  3416   \
# Body_Type                                                       Sedans
# Price                                                            19900
# Vat                                                     VAT deductible
# Km                                                             82000.0
# Previous_Owner                                                     1.0
# kW                                                               110.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A3
# Registration_Year                                                 2016
# Body_Color                                                        Grey
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                            Semi-automatic
# Displacement                                                    1968.0
# Cylinders                                                          4.0
# Drive_Chain                                                        NaN
# Fuel                                                            Diesel
# Comfort_Convenience  [Air conditioning, Armrest, Cruise control, El...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                                   [Alloy wheels, Shift paddles]
# Safety_Security      [ABS, Alarm system, Central door lock, Driver-...
# Gears                                                          [\n6\n]
# Combined_Cons                                                      4.5
#
#                                                                  11656
# Body_Type                                                Station wagon
# Price                                                            17480
# Vat                                                     VAT deductible
# Km                                                             26976.0
# Previous_Owner                                                     1.0
# kW                                                               103.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                         Insignia
# Registration_Year                                                 2017
# Body_Color                                                       White
# Paint_Type                                                         NaN
# Upholstery                                                       Cloth
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                    Manual
# Displacement                                                    1364.0
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                                                          Gasoline
# Comfort_Convenience  [Air conditioning, Armrest, Cruise control, El...
# Entertainment_Media                         [On-board computer, Radio]
# Extras                                                     [Roof rack]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
# Combined_Cons                                                      5.8

# %% [markdown]
# <br>

# %% [markdown]
# #### Gears - Cleaning

# %%
df1.Gears
# Out:
# 0            NaN
# 1        [\n7\n]
# 2            NaN
# 3        [\n6\n]
# 4            NaN
#           ...
# 15914    [\n6\n]
# 15915    [\n7\n]
# 15916    [\n6\n]
# 15917    [\n6\n]
# 15918        NaN
# Name: Gears, Length: 15919, dtype: object

# %%
df1.Gears = df1.Gears.str[0].str.strip('\n')
df1.Gears = df1.Gears.astype(float)
df1.Gears
# Out:
# 0        NaN
# 1        7.0
# 2        NaN
# 3        6.0
# 4        NaN
#         ...
# 15914    6.0
# 15915    7.0
# 15916    6.0
# 15917    6.0
# 15918    NaN
# Name: Gears, Length: 15919, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# #### Comfort_Convenience - Cleaning

# %%
df1.Comfort_Convenience
# Out:
# 0        [Air conditioning, Armrest, Automatic climate ...
# 1        [Air conditioning, Automatic climate control, ...
# 2        [Air conditioning, Cruise control, Electrical ...
# 3        [Air suspension, Armrest, Auxiliary heating, E...
# 4        [Air conditioning, Armrest, Automatic climate ...
#                                ...
# 15914    [Air conditioning, Automatic climate control, ...
# 15915    [Air conditioning, Automatic climate control, ...
# 15916    [Air conditioning, Armrest, Automatic climate ...
# 15917    [Air conditioning, Automatic climate control, ...
# 15918    [Air conditioning, Automatic climate control, ...
# Name: Comfort_Convenience, Length: 15919, dtype: object

# %%
df1.Comfort_Convenience = [",".join(item) if type(item)==list else item for item in df1.Comfort_Convenience]
df1.Comfort_Convenience
# Out:
# 0        Air conditioning,Armrest,Automatic climate con...
# 1        Air conditioning,Automatic climate control,Hil...
# 2        Air conditioning,Cruise control,Electrical sid...
# 3        Air suspension,Armrest,Auxiliary heating,Elect...
# 4        Air conditioning,Armrest,Automatic climate con...
#                                ...
# 15914    Air conditioning,Automatic climate control,Cru...
# 15915    Air conditioning,Automatic climate control,Cru...
# 15916    Air conditioning,Armrest,Automatic climate con...
# 15917    Air conditioning,Automatic climate control,Cru...
# 15918    Air conditioning,Automatic climate control,Cru...
# Name: Comfort_Convenience, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### Entertainment_Media - Cleaning

# %%
df1.Entertainment_Media
# Out:
# 0        [Bluetooth, Hands-free equipment, On-board com...
# 1        [Bluetooth, Hands-free equipment, On-board com...
# 2                                 [MP3, On-board computer]
# 3        [Bluetooth, CD player, Hands-free equipment, M...
# 4        [Bluetooth, CD player, Hands-free equipment, M...
#                                ...
# 15914    [Bluetooth, Digital radio, Hands-free equipmen...
# 15915    [Bluetooth, Digital radio, Hands-free equipmen...
# 15916    [Bluetooth, Hands-free equipment, On-board com...
# 15917               [Bluetooth, Digital radio, Radio, USB]
# 15918                                                [USB]
# Name: Entertainment_Media, Length: 15919, dtype: object

# %%
df1.Entertainment_Media = [",".join(item) if type(item)==list else item for item in df1.Entertainment_Media]
df1.Entertainment_Media
# Out:
# 0        Bluetooth,Hands-free equipment,On-board comput...
# 1        Bluetooth,Hands-free equipment,On-board comput...
# 2                                    MP3,On-board computer
# 3        Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4        Bluetooth,CD player,Hands-free equipment,MP3,O...
#                                ...
# 15914    Bluetooth,Digital radio,Hands-free equipment,O...
# 15915    Bluetooth,Digital radio,Hands-free equipment,R...
# 15916    Bluetooth,Hands-free equipment,On-board comput...
# 15917                    Bluetooth,Digital radio,Radio,USB
# 15918                                                  USB
# Name: Entertainment_Media, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### Extras - Cleaning

# %%
df1.Extras
# Out:
# 0        [Alloy wheels, Catalytic Converter, Voice Cont...
# 1        [Alloy wheels, Sport seats, Sport suspension, ...
# 2                            [Alloy wheels, Voice Control]
# 3               [Alloy wheels, Sport seats, Voice Control]
# 4        [Alloy wheels, Sport package, Sport suspension...
#                                ...
# 15914                         [Alloy wheels, Touch screen]
# 15915          [Alloy wheels, Touch screen, Voice Control]
# 15916                                       [Alloy wheels]
# 15917                         [Alloy wheels, Touch screen]
# 15918                         [Alloy wheels, Touch screen]
# Name: Extras, Length: 15919, dtype: object

# %%
df1.Extras = [",".join(item) if type(item)==list else item for item in df1.Extras]
df1.Extras
# Out:
# 0           Alloy wheels,Catalytic Converter,Voice Control
# 1        Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                               Alloy wheels,Voice Control
# 3                   Alloy wheels,Sport seats,Voice Control
# 4        Alloy wheels,Sport package,Sport suspension,Vo...
#                                ...
# 15914                            Alloy wheels,Touch screen
# 15915              Alloy wheels,Touch screen,Voice Control
# 15916                                         Alloy wheels
# 15917                            Alloy wheels,Touch screen
# 15918                            Alloy wheels,Touch screen
# Name: Extras, Length: 15919, dtype: object

# %% [markdown]
# <br>

# %% [markdown]
# #### Safety_Security - Cleaning

# %%
df1.Safety_Security
# Out:
# 0        [ABS, Central door lock, Daytime running light...
# 1        [ABS, Central door lock, Central door lock wit...
# 2        [ABS, Central door lock, Daytime running light...
# 3        [ABS, Alarm system, Central door lock with rem...
# 4        [ABS, Central door lock, Driver-side airbag, E...
#                                ...
# 15914    [ABS, Central door lock, Central door lock wit...
# 15915    [ABS, Adaptive Cruise Control, Blind spot moni...
# 15916    [ABS, Adaptive Cruise Control, Blind spot moni...
# 15917    [ABS, Blind spot monitor, Driver-side airbag, ...
# 15918    [ABS, Blind spot monitor, Daytime running ligh...
# Name: Safety_Security, Length: 15919, dtype: object

# %%
df1.Safety_Security = [",".join(item) if type(item)==list else item for item in df1.Safety_Security]
df1.Safety_Security
# Out:
# 0        ABS,Central door lock,Daytime running lights,D...
# 1        ABS,Central door lock,Central door lock with r...
# 2        ABS,Central door lock,Daytime running lights,D...
# 3        ABS,Alarm system,Central door lock with remote...
# 4        ABS,Central door lock,Driver-side airbag,Elect...
#                                ...
# 15914    ABS,Central door lock,Central door lock with r...
# 15915    ABS,Adaptive Cruise Control,Blind spot monitor...
# 15916    ABS,Adaptive Cruise Control,Blind spot monitor...
# 15917    ABS,Blind spot monitor,Driver-side airbag,Elec...
# 15918    ABS,Blind spot monitor,Daytime running lights,...
# Name: Safety_Security, Length: 15919, dtype: object

# %%
df1.to_csv("df1_after_cleaning.csv", index = False)
