# %% [markdown]
# ###                               Exploratory Data Analysis (EDA) Project   🏸🧪💻🚀👩‍💻

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
import warnings
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_json("C:/Users/rusla/Downloads/CSV/scout_car.json", lines=True)

# %%
df.sample(20).T
# Out:
#                                                                            11590  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description                             1.6CDTI GS INNOVATION LED+NAVI+AHK
# body_type                                                                 Sedans
# price                                                                      18690
# vat                                                               VAT deductible
# km                                                                     13,500 km
# registration                                                             10/2017
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n114 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                   [\n54944 HC 17\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                         [\n, Red, \n]
# Paint Type                                                                   NaN
# Body Color Original                                               [\nLava Rot\n]
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.3 l/100 km (comb)], [5.1 l/100 km (city)],...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Touch screen, Trailer hitch, Vo...
# \nSafety & Security\n          [ABS, Adaptive headlights, Central door lock, ...
# description                    [\n, LED IntelliLux Scheinwerfer mit AFL Kurve...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            15275  \
# url                            https://www.autoscout24.com//offers/renault-es...
# make_model                                                        Renault Espace
# short_description                              Zen Energy dCi 160 Twin Turbo EDC
# body_type                                                                   None
# price                                                                      17500
# vat                                                                         None
# km                                                                    141,000 km
# registration                                                             05/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        118 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                           [\n, Espace, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                                         NaN
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                                 NaN
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                                 NaN
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4.6 l/100 km (comb)], [5 l/100 km (city)], [...
# CO2 Emission                                           [\n120 g CO2/km (comb)\n]
# Emission Class                                                               NaN
# \nComfort & Convenience\n                                     [Air conditioning]
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\nMás de 2.000 coches en la web de Flexicar ,...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            3565   \
# url                            https://www.autoscout24.com//offers/audi-a3-1-...
# make_model                                                               Audi A3
# short_description                                                        1.6 TDi
# body_type                                                                 Sedans
# price                                                                      15990
# vat                                                                         None
# km                                                                    116,000 km
# registration                                                             07/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         81 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,355 kg\n]
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.7 l/100 km (comb)], [4.2 l/100 km (city)],...
# CO2 Emission                                            [\n98 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Electrical side mi...
# \nEntertainment & Media\n                                 [Bluetooth, CD player]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Alarm system, Central door lock with rem...
# description                    [\nsportbak, CO : 99, airco, start stop, navig...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1271   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                                        SPB 1.0 TFSI Attraction
# body_type                                                                Compact
# price                                                                      15490
# vat                                                               VAT deductible
# km                                                                     47,853 km
# registration                                                             04/2017
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         70 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                         [\n15627\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                 [\nGrigio\n]
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                        [\n999 cc\n]
# Cylinders                                                                [\n3\n]
# Weight                                                            [\n1,135 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                    [[5.1 l/100 km (comb)], [6.2 l/100 km (city)],...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Multi-function steering whe...
# \nEntertainment & Media\n                                     [CD player, Radio]
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, E...
# description                    [\n(Rif.15627) - PASSAGGIO DI PROPRIETA ESCLUS...
# Emission Label                                                               NaN
# Gears                                                                    [\n5\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            9019   \
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                        1.3 CDTI n-Joy 75cv S/S 5 PORTE BERLINA
# body_type                                                                Compact
# price                                                                       7800
# vat                                                               VAT deductible
# km                                                                    133,081 km
# registration                                                             04/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         51 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                       [\n2619602\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                 [\nBianco\n]
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                                 NaN
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                                                                  NaN
# CO2 Emission                                                                 NaN
# Emission Class                                                      [[], [], []]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Power windows]
# \nEntertainment & Media\n             [Bluetooth, MP3, On-board computer, Radio]
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, I...
# description                    [\nDEK:[2619602], Per maggiori informazioni, a...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7678   \
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                     K 1.6 Turbo ST AT S&S Ultimate/EURO 6 TEMP
# body_type                                                          Station wagon
# price                                                                      27150
# vat                                                               VAT deductible
# km                                                                          7 km
# registration                                                             01/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        147 kW
# Type                                              [, Pre-registered, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                      \n
# Full Service                                   [\n, \n, \n154 g CO2/km (comb)\n]
# Non-smoking Vehicle                                   [\n, \n, \nEuro 6d-TEMP\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                       [\nLUK 241\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                        [\n, Blue, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nTiefsee-Blau\n]
# Upholstery                                             [\nFull leather, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0035/BHN\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[6.7 l/100 km (comb)], [8.7 l/100 km (city)],...
# CO2 Emission                                           [\n154 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, On-board com...
# \nExtras\n                     [Alloy wheels, Roof rack, Ski bag, Sport seats...
# \nSafety & Security\n          [ABS, Adaptive headlights, Blind spot monitor,...
# description                    [\n, Fahrzeug steht in 14943 Luckenwalde, Schi...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                        NaN
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            13253  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                Expression Tce 120 EDC AIRCO | NAVI | LM-VELGEN
# body_type                                                                Compact
# price                                                                      14740
# vat                                                                         None
# km                                                                     37,828 km
# registration                                                             11/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         88 kW
# Type                                                        [, Used, , Gasoline]
# Previous Owners                                                              NaN
# Next Inspection                                                      \n11/2020\n
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                [\n, \n, \nEuro 6\n]
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                        [\nXX224H\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Grey, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                              [\nGris Platine (licht grijs\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,197 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,054 kg\n]
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Gasoline, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                        [[], [], []]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n                                    [On-board computer]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [Central door lock, Driver-side airbag, Fog li...
# description                    [\nDe verkoopprijs van deze auto is inclusief ...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                [\nNetherlands\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            5502   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                                            SPB 30 TDI Business
# body_type                                                                 Sedans
# price                                                                      23900
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                      [, New, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                        [\nvn5273\n]
# First Registration                                                           NaN
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                            [\nBianco ibis\n]
# Upholstery                                                    [\nCloth, Other\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.4 l/100 km (comb)], [5 l/100 km (city)], [...
# CO2 Emission                                           [\n114 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Central door lock, Driver-side airbag, I...
# description                    [\n, PREZZO COMPRENSIVO DI MESSA SU STRADA ESC...
# Emission Label                                              [\n1 (No sticker)\n]
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            3658   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                                      SPB 30 TDI S tronic Sport
# body_type                                                                 Sedans
# price                                                                      31900
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                             01/2019
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         85 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2019, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                             [\nPart leather, Black\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                            [\n, Semi-automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,360 kg\n]
# Drive chain                                                                  NaN
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[3.9 l/100 km (comb)], [4.1 l/100 km (city)],...
# CO2 Emission                                           [\n103 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, CD player, Hands-free equipment, M...
# \nExtras\n                     [Alloy wheels, Handicapped enabled, Shift padd...
# \nSafety & Security\n          [ABS, Alarm system, Central door lock, Central...
# description                    [\n, Visita il ns. sito :, www.erreesse-auto.i...
# Emission Label                                                               NaN
# Gears                                                                    [\n7\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            3024   \
# url                            https://www.autoscout24.com//offers/audi-a3-sp...
# make_model                                                               Audi A3
# short_description                          SPB 2.0 TDI 150 CV clean diesel quatt
# body_type                                                                 Sedans
# price                                                                      15500
# vat                                                                         None
# km                                                                    138,000 km
# registration                                                             01/2016
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                                          [, Used, , Diesel]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A3, \n]
# Offer Number                                                                 NaN
# First Registration                                                [\n, 2016, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                          NaN
# Upholstery                                                                   NaN
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,968 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,465 kg\n]
# Drive chain                                                            [\n4WD\n]
# Fuel                                                            [\n, Diesel, \n]
# Consumption                    [[4.8 l/100 km (comb)], [5.7 l/100 km (city)],...
# CO2 Emission                                           [\n125 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Navigation system, Split re...
# \nEntertainment & Media\n                                     [Bluetooth, Radio]
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n          [ABS, Alarm system, Central door lock, Driver-...
# description                    [\nAUTO AZIENDALE, FATTURABILE CON IVA ESPOSTA...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                      [\nItaly\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1777   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description              Sportback 1.4 TDI design Navi+/Xenon/PDC+/SitzHzg
# body_type                                                                 Sedans
# price                                                                      16949
# vat                                                               VAT deductible
# km                                                                     22,601 km
# registration                                                             07/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                         66 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n102 g CO2/km (comb)\n]
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# ...
# Nr. of Doors                                                             [\n4\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                                  NaN
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.5 l/100 km (comb)], [7.2 l/100 km (city)],...
# CO2 Emission                                           [\n127 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Cruise control, Electrical ...
# \nEntertainment & Media\n      [Bluetooth, Digital radio, Hands-free equipmen...
# \nExtras\n                           [Alloy wheels, Touch screen, Voice Control]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Quarzgrau-Metallic, Komfortsitze Stoff Ta...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            1656   \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A1
# short_description                   Sportback sport 1.4 TFSI COD S tronic (Navi)
# body_type                                                                 Sedans
# price                                                                      21940
# vat                                                               VAT deductible
# km                                                                      9,998 km
# registration                                                             03/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                            \n1\n
# Next Inspection                           [\n03/2021\n, \n109 g CO2/km (comb)\n]
# Inspection new                                                               NaN
# Warranty                                                    [\n, \n, \nEuro 6\n]
# Full Service                                             [\n, \n, \n4 (Green)\n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nAudi\n
# Model                                                               [\n, A1, \n]
# Offer Number                                                         [\n44761\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, White, \n]
# Paint Type                                                                   NaN
# Body Color Original                                            [\nCortinaweiß\n]
# Upholstery                                                     [\nCloth, Grey\n]
# Body                                                            [\n, Sedans, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                        [\n0588/BDD\n]
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,395 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[4.7 l/100 km (comb)], [5.8 l/100 km (city)],...
# CO2 Emission                                           [\n109 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Sport seat...
# \nSafety & Security\n          [ABS, Daytime running lights, Driver-side airb...
# description                    [\n, Highlights:,  Anschlussgarantie 3 Jahre m...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            12899  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description               Sports Tourer 1.6 CDTI EcoTEC Business Executive
# body_type                                                          Station wagon
# price                                                                      25955
# vat                                                               VAT deductible
# km                                                                          - km
# registration                                                                 -/-
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                      [, New, , Diesel (Particulate Filter)]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                [\nYes\n, \n125 g CO2/km (comb)\n]
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                   [\n, \n, \nEuro 6d-TEMP\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                         [\n71303\n]
# First Registration                                                           NaN
# Body Color                                                                   NaN
# Paint Type                                                                   NaN
# Body Color Original                            [\nwählbar - ggf. mit Aufpreis\n]
# Upholstery                                                    [\nCloth, Other\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,537 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                    [[4.8 l/100 km (comb)], [5.8 l/100 km (city)],...
# CO2 Emission                                           [\n125 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Automatic climate ...
# \nEntertainment & Media\n      [Bluetooth, Digital radio, On-board computer, ...
# \nExtras\n                     [Alloy wheels, Catalytic Converter, Roof rack,...
# \nSafety & Security\n          [ABS, Adaptive Cruise Control, Central door lo...
# description                    [\n,  , Neues Fahrzeug inkl.19% MWST, Fahrzeug...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n6\n]
# Country version                                                [\nNetherlands\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                        \nin 90 days from ordering\n
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            7147
# url                            https://www.autoscout24.com//offers/opel-astra...
# make_model                                                            Opel Astra
# short_description                     K ST 1.4 ON S/S AUTOMATIK+NAVI+RFK+AGR+AWR
# body_type                                                          Station wagon
# price                                                                      18450
# vat                                                               VAT deductible
# km                                                                     19,929 km
# registration                                                             06/2018
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        110 kW
# Type                                         [, Used, , Super 95 / Super E10 95]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                             [\nYes\n, \nEuro 6\n]
# Warranty                                                 [\n, \n, \n4 (Green)\n]
# Full Service                                                            [\n, \n]
# Non-smoking Vehicle                                                     [\n, \n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Astra, \n]
# Offer Number                                                    [\n8061412-14\n]
# First Registration                                                [\n, 2018, \n]
# Body Color                                                       [\n, Black, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                           [\nOnyx Schwarz\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,399 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                           [\n, Super 95 / Super E10 95, \n]
# Consumption                                                                  NaN
# CO2 Emission                                                                 NaN
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Armrest, Cruise control, El...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                                             [Roof rack, Touch screen]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Fahrtauglich, Herstellergarantie, Euro6, ...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n6\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                    [[], [], []]
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %% [markdown]
# ### 🛑 Drop the columns / rows determined unnecessary as a result of the analysis 💣 🧨

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %% [markdown]
# ###    🛑 Lets see which columns has NaN values
# It shows us the percentage of NaN values, if it is not a significant column and if there are more than 40% NaN values, we need to drop them.

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# url                                0.000000
# make_model                         0.000000
# short_description                  0.288963
# body_type                          0.376908
# price                              0.000000
# vat                               28.349771
# km                                 0.000000
# registration                       0.000000
# prev_owner                        42.892141
# kW                               100.000000
# hp                                 0.000000
# Type                               0.012564
# Previous Owners                   41.711163
# Next Inspection                   77.793831
# Inspection new                    75.299956
# Warranty                          34.047365
# Full Service                      48.395000
# Non-smoking Vehicle               54.915510
# null                               0.000000
# Make                               0.000000
# Model                              0.000000
# Offer Number                      19.944720
# First Registration                10.032037
# Body Color                         3.750236
# Paint Type                        36.258559
# Body Color Original               23.613292
# Upholstery                        23.368302
# Body                               0.376908
# Nr. of Doors                       1.331742
# Nr. of Seats                       6.137320
# Model Code                        68.729192
# Gearing Type                       0.000000
# Displacement                       3.115774
# Cylinders                         35.680633
# Weight                            43.809285
# Drive chain                       43.080596
# Fuel                               0.000000
# Consumption                       11.973114
# CO2 Emission                      11.357497
# Emission Class                    18.977323
# \nComfort & Convenience\n          5.779257
# \nEntertainment & Media\n          8.631195
# \nExtras\n                        18.606696
# \nSafety & Security\n              6.168729
# description                        0.000000
# Emission Label                    74.967021
# Gears                             29.599849
# Country version                   52.346253
# Electricity consumption           99.139393
# Last Service Date                 96.444500
# Other Fuel Types                  94.472015
# Availability                      96.011056
# Last Timing Belt Service Date     99.899491
# Available from                    98.291350
# dtype: float64

# %%
df1 = df.copy()

# %%
df1.sample(3).T
# Out:
#                                                                            13288  \
# url                            https://www.autoscout24.com//offers/renault-cl...
# make_model                                                          Renault Clio
# short_description                          GT Energy TCe 88 kW (120 CV) EDC eco2
# body_type                                                                Compact
# price                                                                      12545
# vat                                                                         None
# km                                                                     23,491 km
# registration                                                             11/2016
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         88 kW
# Type                                                        [, Used, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n12 months\n
# Full Service                                   [\n, \n, \n120 g CO2/km (comb)\n]
# Non-smoking Vehicle                                         [\n, \n, \nEuro 6\n]
# null                                                                          []
# Make                                                                 \nRenault\n
# Model                                                             [\n, Clio, \n]
# Offer Number                                                       [\n9073JVB\n]
# First Registration                                                [\n, 2016, \n]
# Body Color                                                        [\n, Blue, \n]
# Paint Type                                                        [\nMetallic\n]
# Body Color Original                                                          NaN
# Upholstery                                                           [\nBlack\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,197 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                            [\n1,079 kg\n]
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.4 l/100 km (comb)], [6.8 l/100 km (city)],...
# CO2 Emission                                           [\n120 g CO2/km (comb)\n]
# Emission Class                                                      [\nEuro 6\n]
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n                                                    NaN
# \nExtras\n                                                        [Alloy wheels]
# \nSafety & Security\n                              [Immobilizer, LED Headlights]
# description                    [\n, 9073JVB, Oferta de financiación, consulta...
# Emission Label                                                               NaN
# Gears                                                                    [\n6\n]
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            10606  \
# url                            https://www.autoscout24.com//offers/opel-insig...
# make_model                                                         Opel Insignia
# short_description              Sport Tourer OPEL Sport Tourer 1.6 CDTI 136 ch...
# body_type                                                          Station wagon
# price                                                                      15300
# vat                                                                         None
# km                                                                     69,145 km
# registration                                                             02/2017
# prev_owner                                                      1 previous owner
# kW                                                                           NaN
# hp                                                                        100 kW
# Type                                     [, Used, , Diesel (Particulate Filter)]
# Previous Owners                                                            \n1\n
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                                     NaN
# Full Service                                                                 NaN
# Non-smoking Vehicle                                                          NaN
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                         [\n, Insignia, \n]
# Offer Number                                                       [\n1512186\n]
# First Registration                                                [\n, 2017, \n]
# Body Color                                                      [\n, Silver, \n]
# Paint Type                                                                   NaN
# Body Color Original                                                [\nArgento\n]
# Upholstery                                                                   NaN
# Body                                                     [\n, Station wagon, \n]
# Nr. of Doors                                                             [\n5\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                 [\n, Automatic, \n]
# Displacement                                                      [\n1,598 cc\n]
# Cylinders                                                                    NaN
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                       [\n, Diesel (Particulate Filter), \n]
# Consumption                                                                  NaN
# CO2 Emission                                                        [[], [], []]
# Emission Class                                                               NaN
# \nComfort & Convenience\n      [Air conditioning, Automatic climate control, ...
# \nEntertainment & Media\n      [Bluetooth, CD player, On-board computer, Radi...
# \nExtras\n                                                                   NaN
# \nSafety & Security\n          [Alarm system, Central door lock, Driver-side ...
# description                    [\nDEK:[1512186], Con la formula Rent2Buy è po...
# Emission Label                                                               NaN
# Gears                                                                        NaN
# Country version                                                              NaN
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN
#
#                                                                            10182
# url                            https://www.autoscout24.com//offers/opel-corsa...
# make_model                                                            Opel Corsa
# short_description                   Selection Cool & Sound Klima/IntelliLink 4.0
# body_type                                                                Compact
# price                                                                      10990
# vat                                                               VAT deductible
# km                                                                          5 km
# registration                                                             05/2019
# prev_owner                                                                  None
# kW                                                                           NaN
# hp                                                                         51 kW
# Type                                              [, Pre-registered, , Super 95]
# Previous Owners                                                              NaN
# Next Inspection                                                              NaN
# Inspection new                                                               NaN
# Warranty                                                           \n24 months\n
# Full Service                                                                 NaN
# Non-smoking Vehicle                            [\n, \n, \n129 g CO2/km (comb)\n]
# null                                                                          []
# Make                                                                    \nOpel\n
# Model                                                            [\n, Corsa, \n]
# Offer Number                                                  [\nK6045349-352\n]
# First Registration                                                [\n, 2019, \n]
# Body Color                                                        [\n, Blue, \n]
# Paint Type                                                                   NaN
# Body Color Original                                        [\nindigoblau (p2)\n]
# Upholstery                                                    [\nCloth, Black\n]
# Body                                                           [\n, Compact, \n]
# Nr. of Doors                                                             [\n3\n]
# Nr. of Seats                                                             [\n5\n]
# Model Code                                                                   NaN
# Gearing Type                                                    [\n, Manual, \n]
# Displacement                                                      [\n1,229 cc\n]
# Cylinders                                                                [\n4\n]
# Weight                                                                       NaN
# Drive chain                                                          [\nfront\n]
# Fuel                                                          [\n, Super 95, \n]
# Consumption                    [[5.5 l/100 km (comb)], [7.2 l/100 km (city)],...
# CO2 Emission                                           [\n129 g CO2/km (comb)\n]
# Emission Class                                                [\nEuro 6d-TEMP\n]
# \nComfort & Convenience\n      [Air conditioning, Electrical side mirrors, Hi...
# \nEntertainment & Media\n      [Bluetooth, Hands-free equipment, MP3, On-boar...
# \nExtras\n                                                        [Touch screen]
# \nSafety & Security\n          [ABS, Central door lock, Daytime running light...
# description                    [\n, Getriebe:,  Schaltgetriebe, Technik:,  Bo...
# Emission Label                                                   [\n4 (Green)\n]
# Gears                                                                    [\n5\n]
# Country version                                                    [\nGermany\n]
# Electricity consumption                                                      NaN
# Last Service Date                                                            NaN
# Other Fuel Types                                                             NaN
# Availability                                                                 NaN
# Last Timing Belt Service Date                                                NaN
# Available from                                                               NaN

# %%
df1.drop(['url','make_model','short_description','kW','registration','Previous Owners','Next Inspection','Inspection new','Full Service','null','Body Color Original','Body','Model Code','Weight','description','Emission Label','Country version','Electricity consumption','Last Service Date','Other Fuel Types','Availability','Last Timing Belt Service Date','Available from','Non-smoking Vehicle','Offer Number','Warranty'],axis = 1, inplace = True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 28 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   body_type                15859 non-null  object
#  1   price                    15919 non-null  int64
#  2   vat                      11406 non-null  object
#  3   km                       15919 non-null  object
#  4   prev_owner               9091 non-null   object
#  5   hp                       15919 non-null  object
#  6   Type                     15917 non-null  object
#  7   Make                     15919 non-null  object
#  8   Model                    15919 non-null  object
#  9   First Registration       14322 non-null  object
#  10  Body Color               15322 non-null  object
#  11  Paint Type               10147 non-null  object
#  12  Upholstery               12199 non-null  object
#  13  Nr. of Doors             15707 non-null  object
#  14  Nr. of Seats             14942 non-null  object
#  15  Gearing Type             15919 non-null  object
#  16  Displacement             15423 non-null  object
#  17  Cylinders                10239 non-null  object
#  18  Drive chain              9061 non-null   object
#  19  Fuel                     15919 non-null  object
#  20  Consumption              14013 non-null  object
#  21  CO2 Emission             14111 non-null  object
#  22  Emission Class           12898 non-null  object
#  23
# Comfort & Convenience
#   14999 non-null  object
#  24
# Entertainment & Media
#   14545 non-null  object
#  25
# Extras
#                  12957 non-null  object
#  26
# Safety & Security
#       14937 non-null  object
#  27  Gears                    11207 non-null  object
# dtypes: int64(1), object(27)
# memory usage: 3.4+ MB

# %% [markdown]
# ###  🛑 We need to change some column name and values let's do it... 😎

# %% [markdown]
#    ###             KM 🚗

# %%
df1.km
# Out:
# 0        56,013 km
# 1        80,000 km
# 2        83,450 km
# 3        73,000 km
# 4        16,200 km
#            ...
# 15914         - km
# 15915     9,900 km
# 15916        15 km
# 15917        10 km
# 15918         - km
# Name: km, Length: 15919, dtype: object

# %%
df1.km = df1.km.astype('str').replace('- km', np.nan)
df1.km  = df1.km.str.strip(" km")
df1.km = df1.km.str.replace(",", "")
df1.km = df1.km.astype(float)

# %%
df1.km
# Out:
# 0        56013.0
# 1        80000.0
# 2        83450.0
# 3        73000.0
# 4        16200.0
#           ...
# 15914        NaN
# 15915     9900.0
# 15916       15.0
# 15917       10.0
# 15918        NaN
# Name: km, Length: 15919, dtype: float64

# %% [markdown]
# ### KW

# %%
df1.rename(columns={'hp':'kw'}, inplace = True )
df1.kw = df1.kw.str.strip(' kW')
df1.kw = df1.kw.replace(0,np.nan)
df1.kw = df1.kw.replace('-', np.nan)
df1.kw = df1.kw.astype(float)

# %%
df1.kw
# Out:
# 0         66.0
# 1        141.0
# 2         85.0
# 3         66.0
# 4         66.0
#          ...
# 15914    147.0
# 15915    165.0
# 15916    146.0
# 15917    147.0
# 15918    165.0
# Name: kw, Length: 15919, dtype: float64

# %% [markdown]
# ### Prev_owner

# %%
df1.prev_owner
# Out:
# 0        2 previous owners
# 1                     None
# 2         1 previous owner
# 3         1 previous owner
# 4         1 previous owner
#                ...
# 15914                 None
# 15915     1 previous owner
# 15916     1 previous owner
# 15917                 None
# 15918     1 previous owner
# Name: prev_owner, Length: 15919, dtype: object

# %%
df1.prev_owner = df1.prev_owner.str.strip(' previous owner')
df1.prev_owner = df1.prev_owner.astype(float)
df1.prev_owner
# Out:
# 0        2.0
# 1        NaN
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 15914    NaN
# 15915    1.0
# 15916    1.0
# 15917    NaN
# 15918    1.0
# Name: prev_owner, Length: 15919, dtype: float64

# %% [markdown]
# ### Make 🎈

# %%
df1.Make
# Out:
# 0           \nAudi\n
# 1           \nAudi\n
# 2           \nAudi\n
# 3           \nAudi\n
# 4           \nAudi\n
#             ...
# 15914    \nRenault\n
# 15915    \nRenault\n
# 15916    \nRenault\n
# 15917    \nRenault\n
# 15918    \nRenault\n
# Name: Make, Length: 15919, dtype: object

# %%
df1.Make = df1.Make.str.strip('\n')
df1.Make
# Out:
# 0           Audi
# 1           Audi
# 2           Audi
# 3           Audi
# 4           Audi
#           ...
# 15914    Renault
# 15915    Renault
# 15916    Renault
# 15917    Renault
# 15918    Renault
# Name: Make, Length: 15919, dtype: object

# %% [markdown]
# ### Model ✨

# %%
df1.Model
# Out:
# 0            [\n, A1, \n]
# 1            [\n, A1, \n]
# 2            [\n, A1, \n]
# 3            [\n, A1, \n]
# 4            [\n, A1, \n]
#                ...
# 15914    [\n, Espace, \n]
# 15915    [\n, Espace, \n]
# 15916    [\n, Espace, \n]
# 15917    [\n, Espace, \n]
# 15918    [\n, Espace, \n]
# Name: Model, Length: 15919, dtype: object

# %%
df1.Model=df1.Model.str[1].str.strip('\n')
df1.Model
# Out:
# 0            A1
# 1            A1
# 2            A1
# 3            A1
# 4            A1
#           ...
# 15914    Espace
# 15915    Espace
# 15916    Espace
# 15917    Espace
# 15918    Espace
# Name: Model, Length: 15919, dtype: object

# %% [markdown]
# ### Type 🎀

# %%
df1.Type
# Out:
# 0                  [, Used, , Diesel (Particulate Filter)]
# 1                                     [, Used, , Gasoline]
# 2                  [, Used, , Diesel (Particulate Filter)]
# 3                  [, Used, , Diesel (Particulate Filter)]
# 4                  [, Used, , Diesel (Particulate Filter)]
#                                ...
# 15914               [, New, , Diesel (Particulate Filter)]
# 15915    [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916                         [, Pre-registered, , Diesel]
# 15917                         [, Pre-registered, , Diesel]
# 15918                        [, Demonstration, , Super 95]
# Name: Type, Length: 15919, dtype: object

# %%
df1.Type = df1.Type.str[1]
df1.Type
# Out:
# 0                  Used
# 1                  Used
# 2                  Used
# 3                  Used
# 4                  Used
#               ...
# 15914               New
# 15915              Used
# 15916    Pre-registered
# 15917    Pre-registered
# 15918     Demonstration
# Name: Type, Length: 15919, dtype: object

# %% [markdown]
# ### 🎯 Lets change the column names

# %%
df1.rename(columns={'Type':'Condition'}, inplace = True)
df1.rename(columns={'body_type':'Body_Type'}, inplace = True)
df1.rename(columns={'price':'Price'}, inplace = True)
df1.rename(columns={'vat':'Vat'}, inplace = True)
df1.rename(columns={'prev_owner':'Previous_Owner'}, inplace = True)
df1.rename(columns={'First Registration':'Registration_Year'}, inplace = True)
df1.rename(columns={'Body Color':'Body_Color'}, inplace = True)
df1.rename(columns={'Paint Type':'Paint_Type'}, inplace = True)
df1.rename(columns={'Nr. of Doors':'Nr_of_Doors'}, inplace = True)
df1.rename(columns={'Nr. of Seats':'Nr_of_Seats'}, inplace = True)
df1.rename(columns={'Gearing Type':'Gearing_Type'}, inplace = True)
df1.rename(columns={'CO2 Emission':'CO2_Emission'}, inplace = True)
df1.rename(columns={'Emission Class':'Emission_Class'}, inplace = True)
df1.rename(columns={'\nComfort & Convenience\n':'Comfort_Convenience'}, inplace = True)
df1.rename(columns={'\nEntertainment & Media\n':'Entertainment_Media'}, inplace = True)
df1.rename(columns={'\nExtras\n':'Extras'}, inplace = True)
df1.rename(columns={'\nSafety & Security\n':'Safety & Security'}, inplace = True)
df1.rename(columns={'kw':'kW'}, inplace = True)
df1.rename(columns={'Safety & Security':'Safety_Security'}, inplace = True)
df1.rename(columns={'Drive chain':'Drive_Chain'}, inplace = True)
df1.rename(columns={'km':'Km'}, inplace = True)

# %%
df1.sample(2).T
# Out:
#                                                                   1331  \
# Body_Type                                                      Compact
# Price                                                            15850
# Vat                                                               None
# Km                                                             17768.0
# Previous_Owner                                                     2.0
# kW                                                                92.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A1
# Registration_Year                                       [\n, 2017, \n]
# Body_Color                                             [\n, White, \n]
# Paint_Type                                                         NaN
# Upholstery                                          [\nCloth, Black\n]
# Nr_of_Doors                                                    [\n2\n]
# Nr_of_Seats                                                    [\n4\n]
# Gearing_Type                                          [\n, Manual, \n]
# Displacement                                            [\n1,395 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                        NaN
# Fuel                                                [\n, Gasoline, \n]
# Consumption          [[5.1 l/100 km (comb)], [6.6 l/100 km (city)],...
# CO2_Emission                                 [\n120 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, O...
# Extras                      [Alloy wheels, Sport seats, Voice Control]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
#
#                                                                   106
# Body_Type                                                       Sedans
# Price                                                            18900
# Vat                                                     VAT deductible
# Km                                                             10450.0
# Previous_Owner                                                     NaN
# kW                                                                85.0
# Condition                                                         Used
# Make                                                              Audi
# Model                                                               A1
# Registration_Year                                       [\n, 2018, \n]
# Body_Color                                              [\n, Grey, \n]
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                    [\n5\n]
# Nr_of_Seats                                                    [\n4\n]
# Gearing_Type                                       [\n, Automatic, \n]
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                      [\n4\n]
# Drive_Chain                                                [\nfront\n]
# Fuel                                                  [\n, Diesel, \n]
# Consumption          [[3.5 l/100 km (comb)], [4.3 l/100 km (city)],...
# CO2_Emission                                  [\n92 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Leather steering wheel, Pow...
# Entertainment_Media                            [CD player, MP3, Radio]
# Extras                      [Alloy wheels, Sport package, Sport seats]
# Safety_Security      [Central door lock, Driver-side airbag, Electr...
# Gears                                                          [\n5\n]

# %% [markdown]
# ### Registration_Year 👓

# %%
df1.Registration_Year
# Out:
# 0        [\n, 2016, \n]
# 1        [\n, 2017, \n]
# 2        [\n, 2016, \n]
# 3        [\n, 2016, \n]
# 4        [\n, 2016, \n]
#               ...
# 15914               NaN
# 15915    [\n, 2019, \n]
# 15916    [\n, 2019, \n]
# 15917    [\n, 2019, \n]
# 15918    [\n, 2019, \n]
# Name: Registration_Year, Length: 15919, dtype: object

# %%
df1.Registration_Year = df1.Registration_Year.str[1]
df1.Registration_Year
# Out:
# 0        2016
# 1        2017
# 2        2016
# 3        2016
# 4        2016
#          ...
# 15914     NaN
# 15915    2019
# 15916    2019
# 15917    2019
# 15918    2019
# Name: Registration_Year, Length: 15919, dtype: object

# %% [markdown]
# ### Body_Color 🚙

# %%
df1.Body_Color
# Out:
# 0        [\n, Black, \n]
# 1          [\n, Red, \n]
# 2        [\n, Black, \n]
# 3        [\n, Brown, \n]
# 4        [\n, Black, \n]
#               ...
# 15914     [\n, Grey, \n]
# 15915     [\n, Grey, \n]
# 15916    [\n, White, \n]
# 15917     [\n, Grey, \n]
# 15918     [\n, Grey, \n]
# Name: Body_Color, Length: 15919, dtype: object

# %%
df1.Body_Color = df1.Body_Color.str[1]

# %%
df1.Body_Color
# Out:
# 0        Black
# 1          Red
# 2        Black
# 3        Brown
# 4        Black
#          ...
# 15914     Grey
# 15915     Grey
# 15916    White
# 15917     Grey
# 15918     Grey
# Name: Body_Color, Length: 15919, dtype: object

# %% [markdown]
# ### Upholstery 🚚

# %%
df1.Upholstery
# Out:
# 0               [\nCloth, Black\n]
# 1                [\nCloth, Grey\n]
# 2               [\nCloth, Black\n]
# 3                              NaN
# 4               [\nCloth, Black\n]
#                    ...
# 15914                          NaN
# 15915                  [\nCloth\n]
# 15916    [\nFull leather, Black\n]
# 15917           [\nPart leather\n]
# 15918    [\nFull leather, Brown\n]
# Name: Upholstery, Length: 15919, dtype: object

# %%
df1["Upholstery"] = df1["Upholstery"].str[0].str.strip('\n')

# %%
df1.Upholstery
# Out:
# 0               Cloth, Black
# 1                Cloth, Grey
# 2               Cloth, Black
# 3                        NaN
# 4               Cloth, Black
#                 ...
# 15914                    NaN
# 15915                  Cloth
# 15916    Full leather, Black
# 15917           Part leather
# 15918    Full leather, Brown
# Name: Upholstery, Length: 15919, dtype: object

# %% [markdown]
# ### Paint_Type 🚖

# %%
df1.Paint_Type
# Out:
# 0        [\nMetallic\n]
# 1                   NaN
# 2        [\nMetallic\n]
# 3        [\nMetallic\n]
# 4        [\nMetallic\n]
#               ...
# 15914    [\nMetallic\n]
# 15915    [\nMetallic\n]
# 15916               NaN
# 15917               NaN
# 15918    [\nMetallic\n]
# Name: Paint_Type, Length: 15919, dtype: object

# %%
df1.Paint_Type = df1["Paint_Type"].apply(lambda item: item[0] if type(item) == list else item)
df1.Paint_Type = df1.Paint_Type.str.strip('\n')
df1.Paint_Type
# Out:
# 0        Metallic
# 1             NaN
# 2        Metallic
# 3        Metallic
# 4        Metallic
#            ...
# 15914    Metallic
# 15915    Metallic
# 15916         NaN
# 15917         NaN
# 15918    Metallic
# Name: Paint_Type, Length: 15919, dtype: object

# %% [markdown]
# ### Nr. of Doors and Seats 🚒

# %%
df1.Nr_of_Doors
# Out:
# 0        [\n5\n]
# 1        [\n3\n]
# 2        [\n4\n]
# 3        [\n3\n]
# 4        [\n5\n]
#           ...
# 15914    [\n5\n]
# 15915    [\n5\n]
# 15916    [\n5\n]
# 15917    [\n5\n]
# 15918    [\n5\n]
# Name: Nr_of_Doors, Length: 15919, dtype: object

# %%
df1.Nr_of_Doors = df1.Nr_of_Doors.apply(lambda item: item[0] if type(item) == list else item)
df1.Nr_of_Doors = df1.Nr_of_Doors.str.strip('\n')
df1.Nr_of_Doors
# Out:
# 0        5
# 1        3
# 2        4
# 3        3
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    5
# 15917    5
# 15918    5
# Name: Nr_of_Doors, Length: 15919, dtype: object

# %% [markdown]
# ### Nr_of_Seats

# %%
df1.Nr_of_Seats
# Out:
# 0        [\n5\n]
# 1        [\n4\n]
# 2        [\n4\n]
# 3        [\n4\n]
# 4        [\n5\n]
#           ...
# 15914    [\n5\n]
# 15915    [\n5\n]
# 15916    [\n7\n]
# 15917    [\n7\n]
# 15918    [\n5\n]
# Name: Nr_of_Seats, Length: 15919, dtype: object

# %%
df1.Nr_of_Seats = df1.Nr_of_Seats.apply(lambda item: item[0] if type(item) == list else item)
df1.Nr_of_Seats = df1.Nr_of_Seats.str.strip('\n')

# %%
df1.Nr_of_Seats
# Out:
# 0        5
# 1        4
# 2        4
# 3        4
# 4        5
#         ..
# 15914    5
# 15915    5
# 15916    7
# 15917    7
# 15918    5
# Name: Nr_of_Seats, Length: 15919, dtype: object

# %% [markdown]
# ### Gearing Type ✈

# %%
df1.Gearing_Type
# Out:
# 0        [\n, Automatic, \n]
# 1        [\n, Automatic, \n]
# 2        [\n, Automatic, \n]
# 3        [\n, Automatic, \n]
# 4        [\n, Automatic, \n]
#                 ...
# 15914    [\n, Automatic, \n]
# 15915    [\n, Automatic, \n]
# 15916    [\n, Automatic, \n]
# 15917    [\n, Automatic, \n]
# 15918    [\n, Automatic, \n]
# Name: Gearing_Type, Length: 15919, dtype: object

# %%
df1.Gearing_Type = df1.Gearing_Type.apply(lambda item: item[1] if type(item) == list else item)
df1.Gearing_Type = df1.Gearing_Type.str.strip('\n')

# %%
df1.Gearing_Type
# Out:
# 0        Automatic
# 1        Automatic
# 2        Automatic
# 3        Automatic
# 4        Automatic
#            ...
# 15914    Automatic
# 15915    Automatic
# 15916    Automatic
# 15917    Automatic
# 15918    Automatic
# Name: Gearing_Type, Length: 15919, dtype: object

# %% [markdown]
# ### Cylinders  🚑

# %%
df1.Cylinders
# Out:
# 0        [\n3\n]
# 1        [\n4\n]
# 2            NaN
# 3        [\n3\n]
# 4        [\n3\n]
#           ...
# 15914    [\n4\n]
# 15915    [\n4\n]
# 15916    [\n4\n]
# 15917    [\n4\n]
# 15918    [\n4\n]
# Name: Cylinders, Length: 15919, dtype: object

# %%
df1.Cylinders = df1.Cylinders.str[0].str.strip('\n').astype(float)
df1.Cylinders
# Out:
# 0        3.0
# 1        4.0
# 2        NaN
# 3        3.0
# 4        3.0
#         ...
# 15914    4.0
# 15915    4.0
# 15916    4.0
# 15917    4.0
# 15918    4.0
# Name: Cylinders, Length: 15919, dtype: float64

# %% [markdown]
# ### Drice_Chain 🚘

# %%
df1.Drive_Chain
# Out:
# 0        [\nfront\n]
# 1        [\nfront\n]
# 2        [\nfront\n]
# 3                NaN
# 4        [\nfront\n]
#             ...
# 15914    [\nfront\n]
# 15915    [\nfront\n]
# 15916    [\nfront\n]
# 15917    [\nfront\n]
# 15918      [\n4WD\n]
# Name: Drive_Chain, Length: 15919, dtype: object

# %%
df1.Drive_Chain = df1.Drive_Chain.str[0].str.strip('\n')
df1.Drive_Chain
# Out:
# 0        front
# 1        front
# 2        front
# 3          NaN
# 4        front
#          ...
# 15914    front
# 15915    front
# 15916    front
# 15917    front
# 15918      4WD
# Name: Drive_Chain, Length: 15919, dtype: object

# %% [markdown]
# ### Fuel 🚎

# %%
df1.Fuel
# Out:
# 0                    [\n, Diesel (Particulate Filter), \n]
# 1                                       [\n, Gasoline, \n]
# 2                    [\n, Diesel (Particulate Filter), \n]
# 3                    [\n, Diesel (Particulate Filter), \n]
# 4                    [\n, Diesel (Particulate Filter), \n]
#                                ...
# 15914                [\n, Diesel (Particulate Filter), \n]
# 15915    [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                     [\n, Diesel, \n]
# 15917                                     [\n, Diesel, \n]
# 15918                                   [\n, Super 95, \n]
# Name: Fuel, Length: 15919, dtype: object

# %%
df1.Fuel.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                    [\n, Diesel (Particulate Filter), \n]
# 1                                       [\n, Gasoline, \n]
# 2                    [\n, Diesel (Particulate Filter), \n]
# 3                    [\n, Diesel (Particulate Filter), \n]
# 4                    [\n, Diesel (Particulate Filter), \n]
#                                ...
# 15914                [\n, Diesel (Particulate Filter), \n]
# 15915    [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                     [\n, Diesel, \n]
# 15917                                     [\n, Diesel, \n]
# 15918                                   [\n, Super 95, \n]
# Name: Fuel, Length: 15919, dtype: object>

# %%
def Fuel_type(x):
    if 'Benzine' in x or 'Gasoline' in x or 'Super' in x:
        return 'Gasoline'
    elif 'Diesel' in x:
        return 'Diesel'
    elif 'LPG' in x:
        return 'LPG'
    else:
        return 'Others'

# %%
df1.Fuel = df1.Fuel.apply(Fuel_type)
df1.Fuel.value_counts()
# Out:
# Others      9744
# Gasoline    3175
# Diesel      2984
# LPG           16
# Name: Fuel, dtype: int64

# %% [markdown]
# ### Consumption 🚦

# %%
df1.Consumption
# Out:
# 0        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1        [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2        [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3        [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4        [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
#                                ...
# 15914    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915    [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917    [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918    [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
# Name: Consumption, Length: 15919, dtype: object

# %%
df1['Combined_Cons'] = df1.Consumption.str[0].str[0].str.split().str[0]

# %%
df1.Combined_Cons=df1.Combined_Cons.astype(float)

# %%
df1.Combined_Cons
# Out:
# 0        3.8
# 1        5.6
# 2        3.8
# 3        3.8
# 4        4.1
#         ...
# 15914    5.3
# 15915    NaN
# 15916    5.3
# 15917    5.3
# 15918    6.8
# Name: Combined_Cons, Length: 15919, dtype: float64

# %%
df1.sample(3).T
# Out:
#                                                                  10411  \
# Body_Type                                                      Compact
# Price                                                            11175
# Vat                                                     VAT deductible
# Km                                                                10.0
# Previous_Owner                                                     NaN
# kW                                                                51.0
# Condition                                                          New
# Make                                                              Opel
# Model                                                            Corsa
# Registration_Year                                                  NaN
# Body_Color                                                        Blue
# Paint_Type                                                         NaN
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                          3
# Nr_of_Seats                                                          5
# Gearing_Type                                                    Manual
# Displacement                                            [\n1,229 cc\n]
# Cylinders                                                          4.0
# Drive_Chain                                                      front
# Fuel                                                            Others
# Consumption          [[5.9 l/100 km (comb)], [7.5 l/100 km (city)],...
# CO2_Emission                                 [\n141 g CO2/km (comb)\n]
# Emission_Class                                      [\nEuro 6d-TEMP\n]
# Comfort_Convenience  [Air conditioning, Electrical side mirrors, Hi...
# Entertainment_Media                                       [MP3, Radio]
# Extras                                                             NaN
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n5\n]
# Combined_Cons                                                      5.9
#
#                                                                  137    \
# Body_Type                                                      Compact
# Price                                                            18333
# Vat                                                     VAT deductible
# Km                                                              5500.0
# Previous_Owner                                                     1.0
# kW                                                                70.0
# Condition                                               Employee's car
# Make                                                              Audi
# Model                                                               A1
# Registration_Year                                                 2018
# Body_Color                                                       Black
# Paint_Type                                                         NaN
# Upholstery                                                 Cloth, Grey
# Nr_of_Doors                                                          4
# Nr_of_Seats                                                          4
# Gearing_Type                                                 Automatic
# Displacement                                              [\n999 cc\n]
# Cylinders                                                          NaN
# Drive_Chain                                                      front
# Fuel                                                            Others
# Consumption          [[4.4 l/100 km (comb)], [5.4 l/100 km (city)],...
# CO2_Emission                                 [\n102 g CO2/km (comb)\n]
# Emission_Class                                            [\nEuro 6\n]
# Comfort_Convenience  [Air conditioning, Electrical side mirrors, Hi...
# Entertainment_Media  [Bluetooth, CD player, Hands-free equipment, M...
# Extras                      [Alloy wheels, Sport seats, Voice Control]
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                              NaN
# Combined_Cons                                                      4.4
#
#                                                                  10908
# Body_Type                                                       Sedans
# Price                                                            14490
# Vat                                                     VAT deductible
# Km                                                             32294.0
# Previous_Owner                                                     NaN
# kW                                                               101.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                         Insignia
# Registration_Year                                                 2017
# Body_Color                                                      Silver
# Paint_Type                                                    Metallic
# Upholstery                                                         NaN
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                    Manual
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                          4.0
# Drive_Chain                                                      front
# Fuel                                                            Diesel
# Consumption          [[4.3 l/100 km (comb)], [5.1 l/100 km (city)],...
# CO2_Emission                                 [\n118 g CO2/km (comb)\n]
# Emission_Class                                                     NaN
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media                                   [Bluetooth, USB]
# Extras                                                  [Alloy wheels]
# Safety_Security                 [Electronic stability control, Isofix]
# Gears                                                          [\n6\n]
# Combined_Cons                                                      4.3

# %%
df1.drop('Consumption', axis = 1, inplace = True)

# %% [markdown]
# #### CO2_Emission - Emission_Class - Dropping

# %%
df1.drop('CO2_Emission', axis = 1, inplace = True)
df1.drop('Emission_Class', axis = 1, inplace = True)

# %%
df1.sample(3).T
# Out:
#                                                                  15778  \
# Body_Type                                                          Van
# Price                                                            34200
# Vat                                                               None
# Km                                                                 1.0
# Previous_Owner                                                     1.0
# kW                                                               118.0
# Condition                                               Employee's car
# Make                                                           Renault
# Model                                                           Espace
# Registration_Year                                                 2018
# Body_Color                                                       White
# Paint_Type                                                         NaN
# Upholstery                                                         NaN
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          7
# Gearing_Type                                                 Automatic
# Displacement                                                       NaN
# Cylinders                                                          4.0
# Drive_Chain                                                        4WD
# Fuel                                                            Diesel
# Comfort_Convenience  [Air conditioning, Automatic climate control, ...
# Entertainment_Media                                       [Radio, USB]
# Extras                                                  [Alloy wheels]
# Safety_Security             [ABS, Isofix, Power steering, Side airbag]
# Gears                                                          [\n6\n]
# Combined_Cons                                                      NaN
#
#                                                                  12223  \
# Body_Type                                                       Sedans
# Price                                                            20890
# Vat                                                     VAT deductible
# Km                                                             24750.0
# Previous_Owner                                                     1.0
# kW                                                               100.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                         Insignia
# Registration_Year                                                 2018
# Body_Color                                                       Black
# Paint_Type                                                         NaN
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                    Manual
# Displacement                                            [\n1,598 cc\n]
# Cylinders                                                          4.0
# Drive_Chain                                                      front
# Fuel                                                            Others
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, Hands-free equipment, On-board com...
# Extras               [Alloy wheels, Catalytic Converter, Voice Cont...
# Safety_Security      [ABS, Central door lock, Daytime running light...
# Gears                                                          [\n6\n]
# Combined_Cons                                                      4.3
#
#                                                                  10709
# Body_Type                                                Station wagon
# Price                                                            15979
# Vat                                                     VAT deductible
# Km                                                            131187.0
# Previous_Owner                                                     1.0
# kW                                                               125.0
# Condition                                                         Used
# Make                                                              Opel
# Model                                                         Insignia
# Registration_Year                                                 2016
# Body_Color                                                       Beige
# Paint_Type                                                    Metallic
# Upholstery                                                Cloth, Black
# Nr_of_Doors                                                          5
# Nr_of_Seats                                                          5
# Gearing_Type                                                 Automatic
# Displacement                                            [\n1,956 cc\n]
# Cylinders                                                          4.0
# Drive_Chain                                                        4WD
# Fuel                                                            Others
# Comfort_Convenience  [Air conditioning, Armrest, Automatic climate ...
# Entertainment_Media  [Bluetooth, Hands-free equipment, MP3, On-boar...
# Extras               [Alloy wheels, Catalytic Converter, Roof rack,...
# Safety_Security      [ABS, Adaptive headlights, Blind spot monitor,...
# Gears                                                          [\n6\n]
# Combined_Cons                                                      6.4

# %% [markdown]
# ### Gears

# %%
df1.Gears
# Out:
# 0            NaN
# 1        [\n7\n]
# 2            NaN
# 3        [\n6\n]
# 4            NaN
#           ...
# 15914    [\n6\n]
# 15915    [\n7\n]
# 15916    [\n6\n]
# 15917    [\n6\n]
# 15918        NaN
# Name: Gears, Length: 15919, dtype: object

# %%
df1.Gears = df1.Gears.str[0].str.strip('\n')
df1.Gears = df1.Gears.astype(float)
df1.Gears
# Out:
# 0        NaN
# 1        7.0
# 2        NaN
# 3        6.0
# 4        NaN
#         ...
# 15914    6.0
# 15915    7.0
# 15916    6.0
# 15917    6.0
# 15918    NaN
# Name: Gears, Length: 15919, dtype: float64

# %% [markdown]
# ### Comfort_Convenience

# %%
df1.Comfort_Convenience
# Out:
# 0        [Air conditioning, Armrest, Automatic climate ...
# 1        [Air conditioning, Automatic climate control, ...
# 2        [Air conditioning, Cruise control, Electrical ...
# 3        [Air suspension, Armrest, Auxiliary heating, E...
# 4        [Air conditioning, Armrest, Automatic climate ...
#                                ...
# 15914    [Air conditioning, Automatic climate control, ...
# 15915    [Air conditioning, Automatic climate control, ...
# 15916    [Air conditioning, Armrest, Automatic climate ...
# 15917    [Air conditioning, Automatic climate control, ...
# 15918    [Air conditioning, Automatic climate control, ...
# Name: Comfort_Convenience, Length: 15919, dtype: object

# %%
df1.Comfort_Convenience = [",".join(item) if type(item)==list else item for item in df1.Comfort_Convenience]
df1.Comfort_Convenience
# Out:
# 0        Air conditioning,Armrest,Automatic climate con...
# 1        Air conditioning,Automatic climate control,Hil...
# 2        Air conditioning,Cruise control,Electrical sid...
# 3        Air suspension,Armrest,Auxiliary heating,Elect...
# 4        Air conditioning,Armrest,Automatic climate con...
#                                ...
# 15914    Air conditioning,Automatic climate control,Cru...
# 15915    Air conditioning,Automatic climate control,Cru...
# 15916    Air conditioning,Armrest,Automatic climate con...
# 15917    Air conditioning,Automatic climate control,Cru...
# 15918    Air conditioning,Automatic climate control,Cru...
# Name: Comfort_Convenience, Length: 15919, dtype: object

# %% [markdown]
# ### Entertainment_Media

# %%
df1.Entertainment_Media
# Out:
# 0        [Bluetooth, Hands-free equipment, On-board com...
# 1        [Bluetooth, Hands-free equipment, On-board com...
# 2                                 [MP3, On-board computer]
# 3        [Bluetooth, CD player, Hands-free equipment, M...
# 4        [Bluetooth, CD player, Hands-free equipment, M...
#                                ...
# 15914    [Bluetooth, Digital radio, Hands-free equipmen...
# 15915    [Bluetooth, Digital radio, Hands-free equipmen...
# 15916    [Bluetooth, Hands-free equipment, On-board com...
# 15917               [Bluetooth, Digital radio, Radio, USB]
# 15918                                                [USB]
# Name: Entertainment_Media, Length: 15919, dtype: object

# %%
df1.Entertainment_Media = [",".join(item) if type(item)==list else item for item in df1.Entertainment_Media]
df1.Entertainment_Media
# Out:
# 0        Bluetooth,Hands-free equipment,On-board comput...
# 1        Bluetooth,Hands-free equipment,On-board comput...
# 2                                    MP3,On-board computer
# 3        Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4        Bluetooth,CD player,Hands-free equipment,MP3,O...
#                                ...
# 15914    Bluetooth,Digital radio,Hands-free equipment,O...
# 15915    Bluetooth,Digital radio,Hands-free equipment,R...
# 15916    Bluetooth,Hands-free equipment,On-board comput...
# 15917                    Bluetooth,Digital radio,Radio,USB
# 15918                                                  USB
# Name: Entertainment_Media, Length: 15919, dtype: object

# %% [markdown]
# ### Extras

# %%
df1.Extras
# Out:
# 0        [Alloy wheels, Catalytic Converter, Voice Cont...
# 1        [Alloy wheels, Sport seats, Sport suspension, ...
# 2                            [Alloy wheels, Voice Control]
# 3               [Alloy wheels, Sport seats, Voice Control]
# 4        [Alloy wheels, Sport package, Sport suspension...
#                                ...
# 15914                         [Alloy wheels, Touch screen]
# 15915          [Alloy wheels, Touch screen, Voice Control]
# 15916                                       [Alloy wheels]
# 15917                         [Alloy wheels, Touch screen]
# 15918                         [Alloy wheels, Touch screen]
# Name: Extras, Length: 15919, dtype: object

# %%
df1.Extras = [",".join(item) if type(item)==list else item for item in df1.Extras]
df1.Extras
# Out:
# 0           Alloy wheels,Catalytic Converter,Voice Control
# 1        Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                               Alloy wheels,Voice Control
# 3                   Alloy wheels,Sport seats,Voice Control
# 4        Alloy wheels,Sport package,Sport suspension,Vo...
#                                ...
# 15914                            Alloy wheels,Touch screen
# 15915              Alloy wheels,Touch screen,Voice Control
# 15916                                         Alloy wheels
# 15917                            Alloy wheels,Touch screen
# 15918                            Alloy wheels,Touch screen
# Name: Extras, Length: 15919, dtype: object

# %% [markdown]
# ### Safety_Security

# %%
df1.Safety_Security
# Out:
# 0        [ABS, Central door lock, Daytime running light...
# 1        [ABS, Central door lock, Central door lock wit...
# 2        [ABS, Central door lock, Daytime running light...
# 3        [ABS, Alarm system, Central door lock with rem...
# 4        [ABS, Central door lock, Driver-side airbag, E...
#                                ...
# 15914    [ABS, Central door lock, Central door lock wit...
# 15915    [ABS, Adaptive Cruise Control, Blind spot moni...
# 15916    [ABS, Adaptive Cruise Control, Blind spot moni...
# 15917    [ABS, Blind spot monitor, Driver-side airbag, ...
# 15918    [ABS, Blind spot monitor, Daytime running ligh...
# Name: Safety_Security, Length: 15919, dtype: object

# %%
df1.Safety_Security = [",".join(item) if type(item)==list else item for item in df1.Safety_Security]
df1.Safety_Security
# Out:
# 0        ABS,Central door lock,Daytime running lights,D...
# 1        ABS,Central door lock,Central door lock with r...
# 2        ABS,Central door lock,Daytime running lights,D...
# 3        ABS,Alarm system,Central door lock with remote...
# 4        ABS,Central door lock,Driver-side airbag,Elect...
#                                ...
# 15914    ABS,Central door lock,Central door lock with r...
# 15915    ABS,Adaptive Cruise Control,Blind spot monitor...
# 15916    ABS,Adaptive Cruise Control,Blind spot monitor...
# 15917    ABS,Blind spot monitor,Driver-side airbag,Elec...
# 15918    ABS,Blind spot monitor,Daytime running lights,...
# Name: Safety_Security, Length: 15919, dtype: object

# %%
df1.to_csv("df1_After_cleaning.csv", index = False)
